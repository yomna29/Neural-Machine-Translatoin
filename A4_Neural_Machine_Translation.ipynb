# %% [markdown]
# <a href="https://colab.research.google.com/github/yomna29/Neural-Machine-Translatoin/blob/main/A4_Neural_Machine_Translation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Installing Packages
#
# Install PyTorch using pip. See [https://pytorch.org/](https://pytorch.org/) if you want to install it on your computer.
# In addition, we will also be needing [huggingface](https://huggingface.co/)'s `transformers` and `datasets` libraries, and [nltk](https://www.nltk.org/) to compute the BLEU score.

# %%
# Pytorch is typically already installed in Google Colab (uncomment to install):
# !pip install torch==1.8.0
# or for GPU support:
# !pip install torch==1.8.0+cu111 -f https://download.pytorch.org/whl/torch_stable.html
# !pip install transformers==4.27.0
# !pip install datasets==2.10.0
# NLTK is typically also already installed in Google Colab (uncomment to install):
# !pip install nltk==3.8.1
# Out:
# Requirement already satisfied: transformers==4.27.0 in /usr/local/lib/python3.11/dist-packages (4.27.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from transformers==4.27.0) (3.18.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.11.0 in /usr/local/lib/python3.11/dist-packages (from transformers==4.27.0) (0.31.2)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from transformers==4.27.0) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from transformers==4.27.0) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from transformers==4.27.0) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from transformers==4.27.0) (2024.11.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from transformers==4.27.0) (2.32.3)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in /usr/local/lib/python3.11/dist-packages (from transformers==4.27.0) (0.13.3)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.11/dist-packages (from transformers==4.27.0) (4.67.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.11.0->transformers==4.27.0) (2025.3.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.11.0->transformers==4.27.0) (4.13.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->transformers==4.27.0) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->transformers==4.27.0) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->transformers==4.27.0) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->transformers==4.27.0) (2025.4.26)
# Collecting datasets==2.10.0
#   Using cached datasets-2.10.0-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from datasets==2.10.0) (2.0.2)
# Requirement already satisfied: pyarrow>=6.0.0 in /usr/local/lib/python3.11/dist-packages (from datasets==2.10.0) (18.1.0)
# Requirement already satisfied: dill<0.3.7,>=0.3.0 in /usr/local/lib/python3.11/dist-packages (from datasets==2.10.0) (0.3.6)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from datasets==2.10.0) (2.2.2)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.11/dist-packages (from datasets==2.10.0) (2.32.3)
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.11/dist-packages (from datasets==2.10.0) (4.67.1)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.11/dist-packages (from datasets==2.10.0) (3.5.0)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.11/dist-packages (from datasets==2.10.0) (0.70.14)
# Requirement already satisfied: fsspec>=2021.11.1 in /usr/local/lib/python3.11/dist-packages (from fsspec[http]>=2021.11.1->datasets==2.10.0) (2025.3.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.11/dist-packages (from datasets==2.10.0) (3.11.15)
# Requirement already satisfied: huggingface-hub<1.0.0,>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from datasets==2.10.0) (0.31.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from datasets==2.10.0) (24.2)
# Requirement already satisfied: responses<0.19 in /usr/local/lib/python3.11/dist-packages (from datasets==2.10.0) (0.18.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from datasets==2.10.0) (6.0.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets==2.10.0) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets==2.10.0) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets==2.10.0) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets==2.10.0) (1.6.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets==2.10.0) (6.4.3)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets==2.10.0) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets==2.10.0) (1.20.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0.0,>=0.2.0->datasets==2.10.0) (3.18.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0.0,>=0.2.0->datasets==2.10.0) (4.13.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.19.0->datasets==2.10.0) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.19.0->datasets==2.10.0) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.19.0->datasets==2.10.0) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.19.0->datasets==2.10.0) (2025.4.26)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets==2.10.0) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets==2.10.0) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets==2.10.0) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas->datasets==2.10.0) (1.17.0)
# Using cached datasets-2.10.0-py3-none-any.whl (469 kB)
# Installing collected packages: datasets
#   Attempting uninstall: datasets
#     Found existing installation: datasets 3.6.0
#     Uninstalling datasets-3.6.0:
#       Successfully uninstalled datasets-3.6.0
# Successfully installed datasets-2.10.0

# %% [markdown]
# ## Download NMT data

# %% [markdown]
# We first download the data for NMT, which contains pairs of parallel sentences.

# %%
# !wget --quiet https://princeton-nlp.github.io/cos484/assignments/a4/resources.zip
# !unzip -qo resources.zip

# %% [markdown]
# ## Data preprocessing
# In this section we will write code to load and tokenize the data for NMT.
#
#
# The parallel data is provided as huggingface datasets, one for each split of `train`, `validation` and `test`. We load it via the `load_from_disk` method and inspect its features. If you'd like to know more about these dataset objects, have a look at [this tutorial](https://huggingface.co/docs/datasets/access).

# %%
# !pip install -U datasets
# Out:
# Requirement already satisfied: datasets in /usr/local/lib/python3.11/dist-packages (2.10.0)
# Collecting datasets
#   Using cached datasets-3.6.0-py3-none-any.whl.metadata (19 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from datasets) (3.18.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from datasets) (2.0.2)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.11/dist-packages (from datasets) (18.1.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.11/dist-packages (from datasets) (0.3.6)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from datasets) (2.2.2)
# Requirement already satisfied: requests>=2.32.2 in /usr/local/lib/python3.11/dist-packages (from datasets) (2.32.3)
# Requirement already satisfied: tqdm>=4.66.3 in /usr/local/lib/python3.11/dist-packages (from datasets) (4.67.1)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.11/dist-packages (from datasets) (3.5.0)
# Requirement already satisfied: multiprocess<0.70.17 in /usr/local/lib/python3.11/dist-packages (from datasets) (0.70.14)
# Requirement already satisfied: fsspec<=2025.3.0,>=2023.1.0 in /usr/local/lib/python3.11/dist-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (2025.3.0)
# Requirement already satisfied: huggingface-hub>=0.24.0 in /usr/local/lib/python3.11/dist-packages (from datasets) (0.31.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from datasets) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from datasets) (6.0.2)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.11/dist-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (3.11.15)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.24.0->datasets) (4.13.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets) (2025.4.26)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (1.6.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (6.4.3)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (1.20.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.17.0)
# Using cached datasets-3.6.0-py3-none-any.whl (491 kB)
# Installing collected packages: datasets
#   Attempting uninstall: datasets
#     Found existing installation: datasets 2.10.0
#     Uninstalling datasets-2.10.0:
#       Successfully uninstalled datasets-2.10.0
# Successfully installed datasets-3.6.0

# %%
from datasets import load_from_disk
raw_text_datasets = load_from_disk("resources/parallel_en_fr_corpus")
print("Summary of splits:", raw_text_datasets)
print("First training example:", raw_text_datasets["train"][0])
# Out:
# Summary of splits: DatasetDict({
#     train: Dataset({
#         features: ['text_en', 'text_fr'],
#         num_rows: 8701
#     })
#     validation: Dataset({
#         features: ['text_en', 'text_fr'],
#         num_rows: 485
#     })
#     test: Dataset({
#         features: ['text_en', 'text_fr'],
#         num_rows: 486
#     })
# })
# First training example: {'text_en': 'i m tough .', 'text_fr': 'je suis dure .'}

# %% [markdown]
# You are also provided with two pre-trained tokenizers for the source and target languages respectively, which we can load with the hugginface transfomers library. [This tutorial](https://huggingface.co/docs/transformers/preprocessing#natural-language-processing) provides an introduction to using pre-trained tokenizers and the powerful `AutoTokenizer` class. The tokenizers are based on byte-pair encodings which break words into smaller units. This is aimed at reducing the sparsity of words, as subwords can be shared between different rare words. If you are interested in learning more, see the paper [Neural Machine Translation of Rare Words with Subword Units](https://www.aclweb.org/anthology/P16-1162.pdf).

# %%
from transformers import AutoTokenizer
source_tokenizer = AutoTokenizer.from_pretrained("resources/tokenizer_fr")
target_tokenizer = AutoTokenizer.from_pretrained("resources/tokenizer_en")

print("Vocab size of source language:", source_tokenizer.vocab_size)
print("Vocab size of target language:", target_tokenizer.vocab_size)

# As a demonstration, we will the following English sentence to tokens.
example_sentence = "we have an example"
tokenizer_output = target_tokenizer(example_sentence)
print("\n*** Example ***")
print("Example sentence:", example_sentence)
print("Tokenizer output:", tokenizer_output)

# We convert every token id to its associated string, but find the special character ▁ which indicates the beginning of a word.
# Note that very common words are represented by a single token, while others are split into subunits due to the small vocab size.
# Also note that †he tokenizer already adds special tokens to the beginning and end of the sentence.
decoded_sequence = [target_tokenizer.decode(token) for token in tokenizer_output["input_ids"]]
print("Tokens:", decoded_sequence)

# By replacing the special character ▁ with whitespace, we can reconstruct a legibile sentence,
# which differs from the original example by special tokens, includings <unk> tokens, and minor whitespace differences.
reconstructed = "".join(decoded_sequence).replace("▁", " ")
print("Reconstructed sentence", reconstructed)
# Out:
# Vocab size of source language: 3200
# Vocab size of target language: 3200
#
# *** Example ***
# Example sentence: we have an example
# Tokenizer output: {'input_ids': [1, 64, 324, 103, 266, 1490, 92, 2], 'token_type_ids': [0, 0, 0, 0, 0, 0, 0, 0], 'attention_mask': [1, 1, 1, 1, 1, 1, 1, 1]}
# Tokens: ['<s>', '▁we', '▁have', '▁an', '▁ex', 'amp', 'le', '</s>']
# Reconstructed sentence <s> we have an example</s>

# %% [markdown]
# We now want to convert the entire dataset to token ids.
# Specifically, we want to use the tokenizers to create a dataset with
# features "encoder_input_ids" and "decoder_input_ids", which both have type `List[int]`
# and which will later be the inputs to our encoder-decoder model. We will implement this using the powerful `map` function. You can find its API reference [here](https://huggingface.co/docs/datasets/v2.10.0/en/package_reference/main_classes#datasets.Dataset.map).

# %%
from typing import Dict, List

def map_example(example: Dict[str, str]) -> Dict[str, List[int]]:
    # TODO: Tokenize the source and target text for an entry in the parallel dataset
    # and return a dictionary with the keys "encoder_input_ids" and "decoder_input_ids".
    # You can use `source_tokenizer` and `target_tokenizer`

    encoderids = source_tokenizer(example['text_fr'])['input_ids']              #  truncation=True, padding='max_length', max_length=128
    decoderids = target_tokenizer(example['text_en'])['input_ids']

    return {
        'encoder_input_ids': encoderids,
        'decoder_input_ids': decoderids
    }

   # raise NotImplementedError("The map_item function is not implemented yet")

# When mapped is applied to the DatasetDict object, it will apply `map` separately to each split.
tokenized_datasets = raw_text_datasets.map(map_example, batched=False)

# The `remove_columns` removes the existing text features from the new dataset, as they are no longer needed.
tokenized_datasets = tokenized_datasets.remove_columns(raw_text_datasets.column_names["train"])

# Sanity checks on the new dataset
assert set(tokenized_datasets.column_names["train"]) == {"decoder_input_ids", "encoder_input_ids"}
assert len(tokenized_datasets["train"]) == len(raw_text_datasets["train"])

# %% [markdown]
# ## Transformer model for NMT

# %% [markdown]
# We will now implement a encoder-decoder transformer model.
# We already provide code for the Feedforward Layers and Transformer Blocks, but you will have to implement the MultiHeadAttention and Embedding layer from scratch, as well as registering all the layers in the final EncoderDecoderModel. Pay attention to doc-strings and typing information to understand the context and purpose of each missing code block!

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

import math
from typing import Optional, Dict, List, Tuple

# %%
class MultiHeadAttention(nn.Module):
    def __init__(self,
                 hidden_size: int,
                 num_attention_heads: int,
                 is_causal_attention: bool = False,
                 is_cross_attention: bool = False):
        """Defines a flexible multi-head attention layer.

        This layer should define parameters for the query, key and value projections, as well as the output projection,
        and implement the following steps:
        (1) Project the input vectors using query projection and key projection matrices.
        (2) Compute the head-wise attention scores scaled by 1/sqrt(head_dim)
        (3) Perform appropriate masking to the attention scores using key_padding_mask and optionally causal attention.
        (4) Normalize the head-wise attention scores using softmax.
        (5) Compute the value projections and then aggregate using the normalized attention scores.
        (6) Use the output projection to obtain the final output vectors.
        When is_cross_attention is True, the key and value projections are computed from the encoder outputs.
        Note that we do not use attention weight dropout in this implementation.

        Args:
            hidden_size: The dimensionality of the input vectors.
            num_attention_heads: The number of attention heads.
            is_causal_attention: Whether to use causal masking,
                    where tokens cannot attend to the future tokens on their right.
            is_cross_attention: Whether to use cross attention,
                    where we use different inputs for the key/value vs. query vectors.
        """
        super().__init__()
        assert hidden_size % num_attention_heads == 0, "The hidden size must be divisible by the number of attention heads."
        self.head_dim = hidden_size // num_attention_heads # embedding dimension of query and key vectors per head

        # TODO Initialize the module and its parameters here.
        # This module should be able to handle both full self-attention, causal masked self-attention and cross-attention.
        # IMPORTANT: You are not allowed to use `nn.MultiheadAttention` or `nn.functional.scaled_dot_product_attention`!
        self.num_attention_heads = num_attention_heads
        self.is_causal_attention =  is_causal_attention
        self.is_cross_attention = is_cross_attention

        self.query_proj = nn.Linear(hidden_size,hidden_size)                         # nn.Linear(in_features_size, out_features_size, bias=True) #bias: If set to False, the layer will not learn an additive bias. Default is True.
        self.key_proj =nn.Linear(hidden_size,hidden_size)
        self.value_proj =nn.Linear(hidden_size,hidden_size)
        self.out_proj =nn.Linear(hidden_size,hidden_size)

       # raise NotImplementedError("The __init__ function in TransformerAttention is not implemented yet.")

    def causal_attention_mask(self,
                              sequence_length: int,
                              device: Optional[torch.device] = None) -> torch.FloatTensor:
        """Return a Float tensor that can be added to the (un-normalized) attention scores for causal masking.

        Args:
            sequence_length: width and height of the attention mask tensor.
            device: which torch device the resulting tensor should be on (important if you use GPU).

        Returns:
            A Float tensor of shape (1, 1, sequence_length, sequence_length) on device `device`,
            where the entries above the diagonal contain large negative values,
            which means that a query at position i can't attend to a key at position j>i.
        """

        # TODO Implement the forward function.
        # IMPORTANT: For full credit, you should not use python loops.
        #
        # Hint 1: You can pick an arbitrary large value (e.g., -10^{6}), but note that
        #         using `float("-inf")` might lead to numerical issues and 'nan' values during training.
        #
        # Hint 2: Useful pytorch functions for this are `torch.arange` or `torch.triu`.
        #
        # Hint 3: You can move the tensor you create to a device by calling `tensor.to(device)`
        #
        # You should use this function in `forward` and use the returned tensor to implement causal masking
        # by adding it to the un-normalized attention scores of shape (batch_size, num_heads, sequence_length, sequence_length),
        # as torch will handle broadcasting and expand the first two dimensions to batch size and num_heads.
        #
        # You will the masking tensor to be on the same device as the attention scores's device,
        # which you can via the attribute `tensor.device`.

        # Generate a boolean mask where positions above the diagonal are False

        mask = torch.ones(sequence_length, sequence_length, device=device)
        mask = torch.triu(mask, diagonal=1)  # Upper triangle, excluding diagonal
        mask = (mask == 0).unsqueeze(0).unsqueeze(0)  # Shape (1, 1, L, L)
        return mask

       # raise NotImplementedError("The forward function in TransformerAttention is not implemented yet.")


    def forward(self,
                hidden_states: torch.FloatTensor,
                key_padding_mask: torch.BoolTensor,
                encoder_outputs: Optional[torch.FloatTensor] = None) -> Tuple[torch.FloatTensor, torch.FloatTensor]:
        """Computes scaled dot-product attention and returns the output of the attention layer.

        Args:
            hidden_states: Tensor of shape (batch_size, sequence_length, hidden_size) - the input vectors to the layer.
            key_padding_mask: Tensor of shape (batch_size, sequence_length) indicating which tokens are padding tokens.
                    A `True` entry means that this token should be ignored for the purpose of attention.
                    In the case of cross-attention, the tensor has shape (batch_size, encoder_sequence_length).
            encoder_outputs: Optional tensor of shape (batch_size, encoder_sequence_length, hidden_size).
                    The output vectors of the encoder and only passed if the layer performs cross-attention.

        Returns:
            A (layer_output, attention_weights) where layer_output is a tensor of shape (batch_size, sequence_length, hidden_size)
            and attention_weights are the normalized attention scores in the form of
            a tensor of shape (batch_size, num_attention_heads, number_of_query_tokens, number_of_key_tokens).
        """

        # TODO Implement the forward function.
        # IMPORTANT: For full credit, you should not use python loops. Furthermore,
        #            you are not allowed to use `nn.MultiheadAttention` or `nn.functional.scaled_dot_product_attention`!
        #
        # Hint 1: Use `torch.reshape` to add a new axis for the attention head,
        #         which will allow you to process all attention heads in parallel.
        #
        # Hint 2: You can use `torch.transpose` to swap the order of two axes,
        #         As the attention head dimension should be next to the batch size,
        #         see the shape of the output attention weights.
        #
        # Hint 3: `torch.bmm(matrix1, matrix2)` is useful for computing batched matrix multiplications
        #         If matrix1 has shape (B, M, N) and matrix2 has shape (B, N, P),
        #         it performs `B` matrix multiplications and outputs a tensor of shape (B, M, P).
        #         Alternatively, `torch.einsum` should be very useful.
        #         (We really encourage you to check out the documentation of `torch.einsum`,
        #         it can really make your life easier here.)

        batch_size, seq_len, embed_dim = hidden_states.size()


        # Project input into Q, K, V
        Q = self.query_proj(hidden_states)
        K_source = encoder_outputs if encoder_outputs is not None else hidden_states
        K = self.key_proj(K_source)
        V = self.value_proj(K_source)

        # Reshape to multi-head: (B, num_heads, L, D_per_head)
        D_per_head = embed_dim // self.num_attention_heads
        Q = Q.view(batch_size, seq_len, self.num_attention_heads, D_per_head).transpose(1, 2)
        K = K.view(batch_size, -1, self.num_attention_heads, D_per_head).transpose(1, 2)
        V = V.view(batch_size, -1, self.num_attention_heads, D_per_head).transpose(1, 2)

        # Attention score computation
        scores = torch.matmul(Q, K.transpose(-2, -1)) / (D_per_head ** 0.5)

        # Apply causal mask if needed
        if self.is_causal_attention:
            mask = self.causal_attention_mask(seq_len, Q.device)
            scores = scores.masked_fill(~mask, -1e9)  # Avoid using -inf

        # Apply key padding mask
        if key_padding_mask is not None:
            # Expand mask shape: (B, 1, 1, L_k)
            padding_mask_exp = key_padding_mask.unsqueeze(1).unsqueeze(2)
            scores = scores.masked_fill(padding_mask_exp, -1e9)

        # Compute attention weights
        weights = torch.softmax(scores, dim=-1)

        # Weighted sum of values
        context = torch.matmul(weights, V)

        # Reshape back to (B, L, D)
        context = context.transpose(1, 2).contiguous().view(batch_size, seq_len, embed_dim)

        # Final projection
        output = self.out_proj(context)

        return output, weights

       # raise NotImplementedError("The forward function in TransformerAttention is not implemented yet.")

# %% [markdown]
# Before we move on to the other modules, you should implement a sanity check for your attention implementation:
# 1. We check the dimensions of the output of the layer and
# 2. We plot the attention weights to some toy embedding inputs.
# We assume that the last token in the encoder and the last two tokens in the decoder are pad tokens.

# %%
embed_dim = 8
num_heads = 2
batch_size = 1
encoder_seq_length = 5
decoder_seq_length = 7

encoder_outputs = torch.randn(batch_size, encoder_seq_length, embed_dim)
decoder_inputs = torch.randn(batch_size, decoder_seq_length, embed_dim)

encoder_padding_mask = torch.zeros(batch_size, encoder_seq_length, dtype=torch.bool)
encoder_padding_mask[:, -1] = True # The last encoder token is a padding tokens

decoder_padding_mask = torch.zeros(batch_size, decoder_seq_length, dtype=torch.bool)
decoder_padding_mask[:, -2:] = True # The last two decoder tokens are padding token


cross_attention = MultiHeadAttention(embed_dim, num_heads, is_cross_attention=True)
causal_attention = MultiHeadAttention(embed_dim, num_heads, is_causal_attention=True)

cross_attention_out, cross_attention_weights = cross_attention(decoder_inputs, encoder_padding_mask, encoder_outputs)
causal_attention_out, causal_attention_weights = causal_attention(decoder_inputs, decoder_padding_mask)

# Make sure your outputs have the right hapes
assert cross_attention_out.shape == (batch_size, decoder_seq_length, embed_dim)
assert cross_attention_weights.shape == (batch_size, num_heads, decoder_seq_length, encoder_seq_length)
assert causal_attention_out.shape == (batch_size, decoder_seq_length, embed_dim)
assert causal_attention_weights.shape == (batch_size, num_heads, decoder_seq_length, decoder_seq_length)

# Check that the attention weights are normalized
assert torch.isclose(cross_attention_weights.sum(dim=-1), torch.tensor(1.0)).all()
assert torch.isclose(causal_attention_weights.sum(dim=-1), torch.tensor(1.0)).all()

# Check if the attention masking works
assert torch.isclose(cross_attention_weights[:,:,:,-1], torch.tensor(0.0)).all()
assert torch.isclose(causal_attention_weights[:,:,:,-2:], torch.tensor(0.0)).all()
assert torch.isclose(causal_attention_weights[:,:,2,3:], torch.tensor(0.0)).all()


import matplotlib.pyplot as plt

def plot_attention_matrix(attention_matrix, title):
    """Creates a new figure and plots the normalized attention weights as a heatmap.

    This should provide a colorbar for the scale of the heatmap and label the axes "query token position" and "key token position".
    Args:
        attention_matrix: A numpy array of shape (number_of_query_tokens, number_of_key_tokens)
        title: The title of the plot.
    """
    # TODO Implement this function
    plt.figure(figsize=(10, 8))
    plt.imshow(attention_matrix, aspect='auto', interpolation='nearest', cmap='viridis')
    plt.colorbar()
    plt.title(title)
    plt.xlabel("Key Token Position")
    plt.ylabel("Query Token Position")
    plt.title(title)
    plt.show()
    #raise NotImplementedError("Plotting the attention weights is not implemented yet.")

plot_attention_matrix(cross_attention_weights[0,0].detach().numpy(), "cross-attention, head 1")
plot_attention_matrix(cross_attention_weights[0,1].detach().numpy(), "cross-attention, head 2")
plot_attention_matrix(causal_attention_weights[0,0].detach().numpy(), "causal self-attention, head 1")
plot_attention_matrix(causal_attention_weights[0,1].detach().numpy(), "causal self-attention, head 2")

# %%
class TransformerEmbeddings(nn.Module):
    def __init__(self, vocab_size: int, hidden_size: int, max_sequence_length: int):
        """Defines the embedding layer with learnt positional embeddings.

        This layer defines both the token embeddings and positional embeddings,
        which are added together to form the final embedding.

        Args:
            vocab_size: The size of the vocabulary,
                    used to define the size of the token embedding table.
            hidden_size: The dimensionality of the embedding space for both token embeddings and positional embeddings.
            max_sequence_length: The maximum sequence length of the input sequences,
                    used to define the size of the position embedding table.

        Note that this implementation does not use dropout on the embeddings
        and uses learnt positional embeddings instead of sinusoidal embeddings.
        """
        super().__init__()

        # TODO Initialize the module and its parameters here.
        # You should use `nn.Embedding` for both token embeddings and positional embeddings
        self.token_embeddings = nn.Embedding(vocab_size, hidden_size)
        self.position_embeddings = nn.Embedding(max_sequence_length, hidden_size)
        self.dropout = nn.Dropout(0.1)
        #raise NotImplementedError("The __init__ function in TransformerEmbeddings is not implemented yet.")

    def compute_logits(self, decoder_output: torch.FloatTensor) -> torch.FloatTensor:
        """Computes the logits for the next token prediction given the decoder output.

        Args:
            decoder_output: Tensor of shape (batch_size, sequence_length, hidden_size) - the output of the decoder.

        Returns:
            Tensor of shape (batch_size, sequence_length, vocab_size) containing the logits for the next token prediction.
        """

        # TODO Implement this function
        # Hint: you can access the weight parameter matrix via .weight of an nn.Embedding module:
        # Example:
        # ```embeddings = nn.Embedding(num_embeddings, embedding_dim)
        # assert list(embeddings.weight.shape) == [num_embeddings, embedding_dim]```
        # torch.matmul or F.linear may also be useful here.
        logits= torch.matmul(decoder_output, self.token_embeddings.weight.transpose(0, 1))
        #raise NotImplementedError("The compute_logits function in TransformerEmbeddings is not implemented yet.")
        return logits
    def forward(self, input_ids: torch.LongTensor) -> torch.FloatTensor:
        """Computes the embeddings for the input tokens.

        Args:
            input_ids: Tensor of shape (batch_size, sequence_length) containing the input token ids.

        Returns:
            Tensor of shape (batch_size, sequence_length, hidden_size) containing
                    the sum of token embeddings and position embeddings for the input tokens.
        """

        # TODO Implement the forward pass of the embedding layer.

        sequence_len = input_ids.shape[1]

        # Create position indices and embed them
        pos_indices = torch.arange(0, sequence_len, device=input_ids.device).unsqueeze(0)
        tok_embed = self.token_embeddings(input_ids)
        pos_embed = self.position_embeddings(pos_indices)

        # Combine token and positional embeddings
        combined_embed = tok_embed + pos_embed
        combined_embed = self.dropout(combined_embed)

        return combined_embed
        # IMPORTANT: For full credit, you should not use python loops!

       # raise NotImplementedError("The forward function in TransformerEmbeddings is not implemented yet.")

# %%
class TransformerBlock(nn.Module):
    def __init__(self,
                 hidden_size: int,
                 intermediate_size: int,
                 num_attention_heads: int,
                 hidden_dropout_prob: float,
                 is_decoder: bool = False):
        """Defines a single Transformer block, which can be either for the encoder or the decoder.

        Args:
            hidden_size: The dimensionality of the input and output vectors of this layer.
            intermediate_size: The intermediate size of the feedforward layers.
            num_attention_heads: The number of attention heads.
            hidden_dropout_prob: The dropout probability for the hidden states.
            is_decoder: Whether this block is part of the decoder.
        """
        super().__init__()

        self.is_decoder = is_decoder
        self.self_attention = MultiHeadAttention(hidden_size, num_attention_heads, is_causal_attention=is_decoder)
        self.self_attention_layer_norm = nn.LayerNorm(hidden_size)

        if is_decoder:
            self.cross_attention = MultiHeadAttention(hidden_size, num_attention_heads, is_cross_attention=True)
            self.cross_attention_layer_norm = nn.LayerNorm(hidden_size)

        self.feedforward = nn.Sequential(
            nn.Linear(hidden_size, intermediate_size),
            nn.ReLU(),
            nn.Linear(intermediate_size, hidden_size),
            nn.Dropout(hidden_dropout_prob))
        self.feedforward_layer_norm = nn.LayerNorm(hidden_size)

    def forward(self,
                hidden_states: torch.FloatTensor,
                padding_mask: torch.BoolTensor,
                encoder_outputs: Optional[torch.FloatTensor] = None,
                encoder_padding_mask: Optional[torch.BoolTensor] = None) -> torch.FloatTensor:
        """Defines a single Transformer block, either for the encoder or the decoder.

        Args:
            hidden_states: Tensor of shape (batch_size, sequence_length, hidden_size) - the outputs from the previous layer.
            padding_mask: Tensor of shape (batch_size, sequence_length) indicating which tokens are padding tokens.
                    A `True` entry means that this token should be ignored for the purpose of attention.
            encoder_outputs: Optional tensor of shape (batch_size, encoder_sequence_length, hidden_size),
                    which are the output vectors of the encoder. This argument is only used by decoder blocks.
            encoder_padding_mask: Optional tensor of shape (batch_size, encoder_sequence_length) indicating
                    which encoder tokens are padding tokens. This argument is only used in decoder blocks.
                    A `True` entry means that this token should be ignored for the purpose of attention.

        """
        hidden_states = self.self_attention(hidden_states, padding_mask)[0] + hidden_states
        hidden_states = self.self_attention_layer_norm(hidden_states)

        if self.is_decoder:
            hidden_states = self.cross_attention(hidden_states, encoder_padding_mask, encoder_outputs)[0] + hidden_states
            hidden_states = self.cross_attention_layer_norm(hidden_states)

        hidden_states = self.feedforward(hidden_states) + hidden_states
        hidden_states = self.feedforward_layer_norm(hidden_states)
        return hidden_states

# %%
class EncoderDecoderModel(nn.Module):
    def __init__(self,
                 source_vocab_size: int,
                 target_vocab_size: int,
                 hidden_size: int,
                 intermediate_size: int,
                 num_attention_heads: int,
                 num_encoder_layers: int,
                 num_decoder_layers: int,
                 max_sequence_length: int,
                 hidden_dropout_prob: float):
        """A encoder-decoder transformer model which can be used for NMT.

        Args:
            source_vocab_size: The size of the source vocabulary.
            target_vocab_size: The size of the target vocabulary.
            hidden_size: The dimensionality of all input and output embeddings.
            intermediate_size: The intermediate size in the feedforward layers.
            num_attention_heads: The number of attention heads in each multi-head attention modules.
            num_encoder_layers: The number of transformer blocks in the encoder.
            num_decoder_layers: The number of transformer blocks in the decoder.
            max_sequence_length: The maximum sequence length that this model can handle.
            hidden_dropout_prob: The dropout probability in the hidden state in each block.
        """

        super().__init__()
        # TODO Register the input embedding modules and the encoder and decoder blocks.
        # You should use the TransformerBlock and TransformerEmbeddings sub-modules.
        #
        # Hint: Check out `nn.ModuleList` to register a variable number of sub-modules.
         # Embeddings
        self.encoder_embeddings = TransformerEmbeddings(source_vocab_size, hidden_size, max_sequence_length)
        self.decoder_embeddings = TransformerEmbeddings(target_vocab_size, hidden_size, max_sequence_length)

        # Encoder
        self.encoder_layers = nn.ModuleList([
            TransformerBlock(
                hidden_size=hidden_size,
                intermediate_size=intermediate_size,
                num_attention_heads=num_attention_heads,
                hidden_dropout_prob=hidden_dropout_prob,
                is_decoder=False
            ) for _ in range(num_encoder_layers)
        ])


        # Decoder
        self.decoder_layers = nn.ModuleList([
            TransformerBlock(
                hidden_size=hidden_size,
                intermediate_size=intermediate_size,
                num_attention_heads=num_attention_heads,
                hidden_dropout_prob=hidden_dropout_prob,
                is_decoder=True
            ) for _ in range(num_decoder_layers)
        ])

        # Final linear layer to convert decoder output to logits over target vocabulary
        self.final_linear = nn.Linear(hidden_size, target_vocab_size)
        #raise NotImplementedError("The __init__ function is not implemented yet.")

    def forward_encoder(self, input_ids: torch.LongTensor, padding_mask: torch.BoolTensor) -> torch.FloatTensor:
        """Implement the forward pass of the encoder.

        Args:
            input_ids: tensor of shape (batch_size, sequence_length) containing the input token ids to the encoder.
            padding_mask: tensor of shape (batch_size, sequence_length) indicating which encoder tokens are padding tokens (`True`)
                    and should be ignored in self-attention computations.

        Returns:
            Tensor of shape (batch_size, sequence_length, hidden_size) containing the output embeddings of the encoder.
        """

        # TODO Implement this function
        hidden_states = self.encoder_embeddings(input_ids)

        for layer in self.encoder_layers:
            hidden_states = layer(hidden_states, padding_mask)

        return hidden_states
       # raise NotImplementedError("The forward_encoder function is not implemented yet.")

    def forward_decoder(self,
                        input_ids: torch.LongTensor,
                        padding_mask: torch.BoolTensor,
                        encoder_outputs: torch.FloatTensor,
                        encoder_padding_mask: torch.BoolTensor) -> torch.FloatTensor:
        """Implement the forward pass of the decoder.

        Args:
            input_ids: Tensor of shape (batch_size, sequence_length) containing the input token ids to the decoder.
            padding_mask: Tensor of shape (batch_size, sequence_length) indicating which decoder tokens are padding tokens (`True`)
                    and should be ignored in self-attention computations.
            encoder_outputs: Tensor of shape (batch_size, encoder_sequence_length, hidden_size) containing the output embeddings of the encoder.
            encoder_padding_mask: Tensor of shape (batch_size, encoder_sequence_length) indicating which encoder tokens are padding tokens (`True`)
                    and should be ignored in cross-attention computations.

        Returns:
            Tensor of shape (batch_size, sequence_length, target_vocabulary_size)
            containing the logits for predicting the next token in the target sequence.
        """

        # TODO Implement this function
        hidden_states = self.decoder_embeddings(input_ids)

        for layer in self.decoder_layers:
            hidden_states = layer(hidden_states, padding_mask, encoder_outputs, encoder_padding_mask)

        logits = self.final_linear(hidden_states)
        return logits
       #raise NotImplementedError("The forward_decoder function has to be implemented.")

    def forward(self, encoder_input_ids, encoder_padding_mask, decoder_input_ids, decoder_padding_mask):
        encoder_outputs = self.forward_encoder(encoder_input_ids, encoder_padding_mask)
        decoder_logits = self.forward_decoder(decoder_input_ids, decoder_padding_mask, encoder_outputs, encoder_padding_mask)
        return decoder_logits

# %% [markdown]
# ## Train the model
#
# In this section, we train the seq2seq model on the parallel tokenized corpus.
# Before you start training models, you should implement and test the model and its sub-modules, especially the attention.
#
# First, we implement a `collate` function, which takes a list of examples from the dataset and forms a batch,
# consisting of padded encoder and decoder input ids, as well as encoder and decoder padding masks.

# %%
def collate_fn(examples: List[Dict[str, List[int]]]) -> Dict[str, torch.Tensor]:
    """Collates a list of variable length sequences from the dataset into a batch of pytorch tensors with padding."""

    encoder_sequence_length = max(len(example["encoder_input_ids"]) for example in examples)
    decoder_sequence_length = max(len(example["decoder_input_ids"]) for example in examples)
    batch_size = len(examples)

    encoder_input_ids = torch.full((batch_size, encoder_sequence_length),
                                   fill_value=source_tokenizer.pad_token_id,
                                   dtype=torch.int64)
    encoder_padding_mask = torch.ones((batch_size, encoder_sequence_length),
                                      dtype=torch.bool)

    decoder_input_ids = torch.full((batch_size, decoder_sequence_length),
                                   fill_value=target_tokenizer.pad_token_id,
                                   dtype=torch.int64)
    decoder_padding_mask = torch.ones((batch_size, decoder_sequence_length),
                                      dtype=torch.bool)

    for i, example in enumerate(examples):
        encoder_input_ids[i, :len(example["encoder_input_ids"])] = torch.tensor(example["encoder_input_ids"])
        encoder_padding_mask[i, :len(example["encoder_input_ids"])] = False

        decoder_input_ids[i, :len(example["decoder_input_ids"])] = torch.tensor(example["decoder_input_ids"])
        decoder_padding_mask[i, :len(example["decoder_input_ids"])] = False

    return {"encoder_input_ids": encoder_input_ids,
            "encoder_padding_mask": encoder_padding_mask,
            "decoder_input_ids": decoder_input_ids,
            "decoder_padding_mask": decoder_padding_mask}

# %% [markdown]
# Next, we provide a simple training loop.

# %%
import time
import math

def compute_loss_per_token(model, batch):
    logits = model(**batch)

    valid_label_mask = ~(batch["decoder_padding_mask"][:,1:])
    labels = batch["decoder_input_ids"][:,1:][valid_label_mask]
    logits = logits[:,:-1][valid_label_mask]

    return F.cross_entropy(logits, labels, reduction='none')


def evaluate_perplexity(model, dataset, batch_size=32, device="cpu"):
    model.eval()

    dev_loader = torch.utils.data.DataLoader(
        dataset, batch_size=batch_size, shuffle=False, collate_fn=collate_fn)

    num_tokens = loss_sum = 0

    # no_grad() signals backend to throw away all gradients
    with torch.no_grad():
        for batch in dev_loader:
            # Move tensors in batch to device
            for key in batch:
                batch[key] = batch[key].to(device)

            token_losses = compute_loss_per_token(model, batch)

            loss_sum += token_losses.sum()
            num_tokens += token_losses.numel()

        dev_ppl = (loss_sum / num_tokens).exp().cpu().item()
    return dev_ppl


def train(model, training_dataset, validation_dataset,
          batch_size=32, lr=1e-3, max_epoch=10, log_every=10, valid_niter=100,
          model_path="model.pt"):
    model.train()

    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    print('Use device: %s' % device)

    model = model.to(device)

    optimizer = torch.optim.Adam(model.parameters(), lr=lr)

    epoch = global_step = loss_sum = num_tokens = num_examples = 0
    best_valid_perplexity = float('inf')
    train_time = begin_time = time.time()
    print('Beginning maximum likelihood training')


    while True:
        train_loader = torch.utils.data.DataLoader(
            training_dataset, batch_size=batch_size, shuffle=True, collate_fn=collate_fn)
        epoch += 1
        batches_per_epoch = len(train_loader)
        for i, batch in enumerate(train_loader):
            global_step += 1

            # Move tensors in batch to device
            for key in batch:
                batch[key] = batch[key].to(device)

            optimizer.zero_grad()

            token_losses = compute_loss_per_token(model, batch)
            total_loss = token_losses.sum()

            loss = total_loss / batch_size
            loss.backward()

            optimizer.step()

            loss_sum += total_loss.cpu().item()
            num_tokens += token_losses.numel()
            num_examples += batch_size

            if global_step % log_every == 0:
                average_loss = loss_sum / num_examples
                average_ppl = math.exp(loss_sum / num_tokens)
                print(f"epoch {epoch} ({i}/{batches_per_epoch}) | step {global_step} | "
                      f"avg_nll={average_loss:.2f} avg_ppl={average_ppl:.2f} "
                      f"speed={num_tokens / (time.time() - train_time):.2f} words/sec "
                      f"time_elapsed={time.time() - begin_time:.2f} sec")

                train_time = time.time()
                loss_sum = num_tokens = num_examples = 0.0

            if global_step % valid_niter == 0:
                print('Begin validation ...')
                dev_perplexity = evaluate_perplexity(model, validation_dataset, batch_size=batch_size, device=device)

                print(f"validation: step {global_step} | dev_ppl={dev_perplexity}")

                if dev_perplexity < best_valid_perplexity:
                    best_valid_perplexity = dev_perplexity
                    print(f"epoch {epoch} step {global_step}: save currently the best model to '{model_path}'")
                    torch.save(model.state_dict(), model_path)
                    torch.save(optimizer.state_dict(), model_path + '.optim')
                model.train()

        if epoch == max_epoch:
            print('Reached maximum number of epochs')
            break

# %% [markdown]
# Let's train a relatively small model architecture for 15 epochs.
# With a reasonable implementation, this should take about 16 minutes on CPU / 3 minutes on GPU and we should achieve a validation perplexity of below 10!

# %%
# Set a random seed, so you obtain the same output model if you run this cell again.
seed = 42
torch.manual_seed(seed)
torch.cuda.manual_seed(seed)

model = EncoderDecoderModel(
    source_vocab_size=source_tokenizer.vocab_size,
    target_vocab_size=target_tokenizer.vocab_size,
    hidden_size=32,
    intermediate_size=32 * 4,
    num_attention_heads=4,
    num_encoder_layers=3,
    num_decoder_layers=3,
    max_sequence_length=32,
    hidden_dropout_prob=0.1,
    )

print("Model architecture:", model)
print("Total number of trainable model parameters:", sum(p.numel() for p in model.parameters() if p.requires_grad))

train(model, tokenized_datasets["train"], tokenized_datasets["validation"],
      max_epoch=15, model_path="model.pt")
# Out:
# Model architecture: EncoderDecoderModel(
#   (encoder_embeddings): TransformerEmbeddings(
#     (token_embeddings): Embedding(3200, 32)
#     (position_embeddings): Embedding(32, 32)
#     (dropout): Dropout(p=0.1, inplace=False)
#   )
#   (decoder_embeddings): TransformerEmbeddings(
#     (token_embeddings): Embedding(3200, 32)
#     (position_embeddings): Embedding(32, 32)
#     (dropout): Dropout(p=0.1, inplace=False)
#   )
#   (encoder_layers): ModuleList(
#     (0-2): 3 x TransformerBlock(
#       (self_attention): MultiHeadAttention(
#         (query_proj): Linear(in_features=32, out_features=32, bias=True)
#         (key_proj): Linear(in_features=32, out_features=32, bias=True)
#         (value_proj): Linear(in_features=32, out_features=32, bias=True)
#         (out_proj): Linear(in_features=32, out_features=32, bias=True)
#       )
#       (self_attention_layer_norm): LayerNorm((32,), eps=1e-05, elementwise_affine=True)
#       (feedforward): Sequential(
#         (0): Linear(in_features=32, out_features=128, bias=True)
#         (1): ReLU()
#         (2): Linear(in_features=128, out_features=32, bias=True)
#         (3): Dropout(p=0.1, inplace=False)
#       )
#       (feedforward_layer_norm): LayerNorm((32,), eps=1e-05, elementwise_affine=True)
#     )
#   )
#   (decoder_layers): ModuleList(
#     (0-2): 3 x TransformerBlock(
#       (self_attention): MultiHeadAttention(
#         (query_proj): Linear(in_features=32, out_features=32, bias=True)
#         (key_proj): Linear(in_features=32, out_features=32, bias=True)
#         (value_proj): Linear(in_features=32, out_features=32, bias=True)
#         (out_proj): Linear(in_features=32, out_features=32, bias=True)
#       )
#       (self_attention_layer_norm): LayerNorm((32,), eps=1e-05, elementwise_affine=True)
#       (cross_attention): MultiHeadAttention(
#         (query_proj): Linear(in_features=32, out_features=32, bias=True)
#         (key_proj): Linear(in_features=32, out_features=32, bias=True)
#         (value_proj): Linear(in_features=32, out_features=32, bias=True)
#         (out_proj): Linear(in_features=32, out_features=32, bias=True)
#       )
#       (cross_attention_layer_norm): LayerNorm((32,), eps=1e-05, elementwise_affine=True)
#       (feedforward): Sequential(
#         (0): Linear(in_features=32, out_features=128, bias=True)
#         (1): ReLU()
#         (2): Linear(in_features=128, out_features=32, bias=True)
#         (3): Dropout(p=0.1, inplace=False)
#       )
#       (feedforward_layer_norm): LayerNorm((32,), eps=1e-05, elementwise_affine=True)
#     )
#   )
#   (final_linear): Linear(in_features=32, out_features=3200, bias=True)
# )
# Total number of trainable model parameters: 401536
# Use device: cpu
# Beginning maximum likelihood training
# epoch 1 (9/272) | step 10 | avg_nll=54.67 avg_ppl=2374.09 speed=3330.40 words/sec time_elapsed=0.68 sec
# epoch 1 (19/272) | step 20 | avg_nll=52.17 avg_ppl=1290.16 speed=3592.91 words/sec time_elapsed=1.32 sec
# epoch 1 (29/272) | step 30 | avg_nll=48.76 avg_ppl=796.27 speed=3625.64 words/sec time_elapsed=1.97 sec
# epoch 1 (39/272) | step 40 | avg_nll=44.78 avg_ppl=494.58 speed=3393.64 words/sec time_elapsed=2.65 sec
# epoch 1 (49/272) | step 50 | avg_nll=41.65 avg_ppl=327.07 speed=3476.88 words/sec time_elapsed=3.31 sec
# epoch 1 (59/272) | step 60 | avg_nll=38.37 avg_ppl=212.50 speed=3475.97 words/sec time_elapsed=3.97 sec
# epoch 1 (69/272) | step 70 | avg_nll=35.79 avg_ppl=143.51 speed=3615.82 words/sec time_elapsed=4.61 sec
# epoch 1 (79/272) | step 80 | avg_nll=34.28 avg_ppl=112.91 speed=3318.82 words/sec time_elapsed=5.31 sec
# epoch 1 (89/272) | step 90 | avg_nll=32.22 avg_ppl=82.41 speed=2621.14 words/sec time_elapsed=6.20 sec
# epoch 1 (99/272) | step 100 | avg_nll=29.70 avg_ppl=64.45 speed=2505.16 words/sec time_elapsed=7.11 sec
# Begin validation ...
# validation: step 100 | dev_ppl=52.801666259765625
# epoch 1 step 100: save currently the best model to 'model.pt'
# epoch 1 (109/272) | step 110 | avg_nll=28.56 avg_ppl=53.65 speed=1582.73 words/sec time_elapsed=8.56 sec
# epoch 1 (119/272) | step 120 | avg_nll=27.29 avg_ppl=44.65 speed=3395.40 words/sec time_elapsed=9.24 sec
# epoch 1 (129/272) | step 130 | avg_nll=27.97 avg_ppl=44.57 speed=3849.50 words/sec time_elapsed=9.85 sec
# epoch 1 (139/272) | step 140 | avg_nll=26.59 avg_ppl=38.10 speed=3684.77 words/sec time_elapsed=10.49 sec
# epoch 1 (149/272) | step 150 | avg_nll=25.89 avg_ppl=34.94 speed=3625.14 words/sec time_elapsed=11.13 sec
# epoch 1 (159/272) | step 160 | avg_nll=25.72 avg_ppl=34.26 speed=3473.05 words/sec time_elapsed=11.80 sec
# epoch 1 (169/272) | step 170 | avg_nll=24.39 avg_ppl=29.75 speed=3547.14 words/sec time_elapsed=12.45 sec
# epoch 1 (179/272) | step 180 | avg_nll=25.56 avg_ppl=31.83 speed=3456.17 words/sec time_elapsed=13.13 sec
# epoch 1 (189/272) | step 190 | avg_nll=24.20 avg_ppl=28.26 speed=3748.68 words/sec time_elapsed=13.75 sec
# epoch 1 (199/272) | step 200 | avg_nll=23.65 avg_ppl=27.42 speed=3191.21 words/sec time_elapsed=14.47 sec
# Begin validation ...
# validation: step 200 | dev_ppl=22.95691680908203
# epoch 1 step 200: save currently the best model to 'model.pt'
# epoch 1 (209/272) | step 210 | avg_nll=22.70 avg_ppl=23.92 speed=2383.26 words/sec time_elapsed=15.43 sec
# epoch 1 (219/272) | step 220 | avg_nll=23.49 avg_ppl=25.39 speed=3418.67 words/sec time_elapsed=16.11 sec
# epoch 1 (229/272) | step 230 | avg_nll=23.87 avg_ppl=25.99 speed=3685.15 words/sec time_elapsed=16.74 sec
# epoch 1 (239/272) | step 240 | avg_nll=22.84 avg_ppl=22.73 speed=3486.18 words/sec time_elapsed=17.42 sec
# epoch 1 (249/272) | step 250 | avg_nll=23.52 avg_ppl=25.02 speed=3595.86 words/sec time_elapsed=18.07 sec
# epoch 1 (259/272) | step 260 | avg_nll=22.56 avg_ppl=22.34 speed=3026.75 words/sec time_elapsed=18.83 sec
# epoch 1 (269/272) | step 270 | avg_nll=21.67 avg_ppl=20.27 speed=2409.07 words/sec time_elapsed=19.79 sec
# epoch 2 (7/272) | step 280 | avg_nll=21.78 avg_ppl=20.54 speed=2431.36 words/sec time_elapsed=20.74 sec
# epoch 2 (17/272) | step 290 | avg_nll=21.05 avg_ppl=19.01 speed=1954.26 words/sec time_elapsed=21.91 sec
# epoch 2 (27/272) | step 300 | avg_nll=21.36 avg_ppl=19.10 speed=3416.40 words/sec time_elapsed=22.59 sec
# Begin validation ...
# validation: step 300 | dev_ppl=18.0816650390625
# epoch 2 step 300: save currently the best model to 'model.pt'
# epoch 2 (37/272) | step 310 | avg_nll=20.86 avg_ppl=18.28 speed=2394.84 words/sec time_elapsed=23.55 sec
# epoch 2 (47/272) | step 320 | avg_nll=22.04 avg_ppl=20.23 speed=3851.39 words/sec time_elapsed=24.16 sec
# epoch 2 (57/272) | step 330 | avg_nll=21.77 avg_ppl=20.05 speed=3813.31 words/sec time_elapsed=24.77 sec
# epoch 2 (67/272) | step 340 | avg_nll=20.98 avg_ppl=18.29 speed=3478.41 words/sec time_elapsed=25.43 sec
# epoch 2 (77/272) | step 350 | avg_nll=21.06 avg_ppl=18.10 speed=3594.02 words/sec time_elapsed=26.08 sec
# epoch 2 (87/272) | step 360 | avg_nll=21.96 avg_ppl=19.88 speed=3612.57 words/sec time_elapsed=26.73 sec
# epoch 2 (97/272) | step 370 | avg_nll=20.33 avg_ppl=17.06 speed=3462.11 words/sec time_elapsed=27.39 sec
# epoch 2 (107/272) | step 380 | avg_nll=21.70 avg_ppl=18.92 speed=3642.90 words/sec time_elapsed=28.04 sec
# epoch 2 (117/272) | step 390 | avg_nll=21.15 avg_ppl=18.42 speed=3759.31 words/sec time_elapsed=28.66 sec
# epoch 2 (127/272) | step 400 | avg_nll=20.32 avg_ppl=16.91 speed=3720.76 words/sec time_elapsed=29.28 sec
# Begin validation ...
# validation: step 400 | dev_ppl=16.28804588317871
# epoch 2 step 400: save currently the best model to 'model.pt'
# epoch 2 (137/272) | step 410 | avg_nll=20.41 avg_ppl=17.15 speed=2437.50 words/sec time_elapsed=30.22 sec
# epoch 2 (147/272) | step 420 | avg_nll=20.54 avg_ppl=17.09 speed=3559.00 words/sec time_elapsed=30.87 sec
# epoch 2 (157/272) | step 430 | avg_nll=20.36 avg_ppl=16.68 speed=3840.82 words/sec time_elapsed=31.47 sec
# epoch 2 (167/272) | step 440 | avg_nll=20.42 avg_ppl=16.52 speed=3320.83 words/sec time_elapsed=32.17 sec
# epoch 2 (177/272) | step 450 | avg_nll=20.87 avg_ppl=17.37 speed=2573.25 words/sec time_elapsed=33.08 sec
# epoch 2 (187/272) | step 460 | avg_nll=20.21 avg_ppl=15.94 speed=2416.17 words/sec time_elapsed=34.05 sec
# epoch 2 (197/272) | step 470 | avg_nll=19.40 avg_ppl=15.02 speed=2520.35 words/sec time_elapsed=34.96 sec
# epoch 2 (207/272) | step 480 | avg_nll=19.52 avg_ppl=15.23 speed=3626.00 words/sec time_elapsed=35.59 sec
# epoch 2 (217/272) | step 490 | avg_nll=19.93 avg_ppl=15.65 speed=3577.80 words/sec time_elapsed=36.24 sec
# epoch 2 (227/272) | step 500 | avg_nll=20.01 avg_ppl=15.43 speed=3795.17 words/sec time_elapsed=36.86 sec
# Begin validation ...
# validation: step 500 | dev_ppl=14.096153259277344
# epoch 2 step 500: save currently the best model to 'model.pt'
# epoch 2 (237/272) | step 510 | avg_nll=19.26 avg_ppl=14.67 speed=2461.35 words/sec time_elapsed=37.79 sec
# epoch 2 (247/272) | step 520 | avg_nll=20.44 avg_ppl=16.13 speed=3588.20 words/sec time_elapsed=38.45 sec
# epoch 2 (257/272) | step 530 | avg_nll=19.87 avg_ppl=15.51 speed=3559.84 words/sec time_elapsed=39.10 sec
# epoch 2 (267/272) | step 540 | avg_nll=19.58 avg_ppl=14.99 speed=3614.04 words/sec time_elapsed=39.74 sec
# epoch 3 (5/272) | step 550 | avg_nll=18.31 avg_ppl=13.40 speed=3348.57 words/sec time_elapsed=40.41 sec
# epoch 3 (15/272) | step 560 | avg_nll=18.34 avg_ppl=13.26 speed=3179.38 words/sec time_elapsed=41.13 sec
# epoch 3 (25/272) | step 570 | avg_nll=19.95 avg_ppl=14.73 speed=3875.18 words/sec time_elapsed=41.74 sec
# epoch 3 (35/272) | step 580 | avg_nll=19.13 avg_ppl=14.07 speed=3764.38 words/sec time_elapsed=42.35 sec
# epoch 3 (45/272) | step 590 | avg_nll=18.26 avg_ppl=12.70 speed=3796.32 words/sec time_elapsed=42.96 sec
# epoch 3 (55/272) | step 600 | avg_nll=18.84 avg_ppl=13.98 speed=3630.98 words/sec time_elapsed=43.59 sec
# Begin validation ...
# validation: step 600 | dev_ppl=13.034103393554688
# epoch 3 step 600: save currently the best model to 'model.pt'
# epoch 3 (65/272) | step 610 | avg_nll=19.15 avg_ppl=13.93 speed=2367.62 words/sec time_elapsed=44.57 sec
# epoch 3 (75/272) | step 620 | avg_nll=19.73 avg_ppl=15.04 speed=2912.17 words/sec time_elapsed=45.37 sec
# epoch 3 (85/272) | step 630 | avg_nll=19.54 avg_ppl=14.55 speed=2579.27 words/sec time_elapsed=46.28 sec
# epoch 3 (95/272) | step 640 | avg_nll=19.54 avg_ppl=14.46 speed=2382.49 words/sec time_elapsed=47.26 sec
# epoch 3 (105/272) | step 650 | avg_nll=19.09 avg_ppl=13.64 speed=2969.94 words/sec time_elapsed=48.05 sec
# epoch 3 (115/272) | step 660 | avg_nll=19.05 avg_ppl=13.55 speed=3680.93 words/sec time_elapsed=48.68 sec
# epoch 3 (125/272) | step 670 | avg_nll=17.97 avg_ppl=12.10 speed=3897.37 words/sec time_elapsed=49.27 sec
# epoch 3 (135/272) | step 680 | avg_nll=18.07 avg_ppl=12.29 speed=3624.65 words/sec time_elapsed=49.91 sec
# epoch 3 (145/272) | step 690 | avg_nll=17.63 avg_ppl=12.08 speed=3529.25 words/sec time_elapsed=50.55 sec
# epoch 3 (155/272) | step 700 | avg_nll=18.42 avg_ppl=12.61 speed=3560.64 words/sec time_elapsed=51.21 sec
# Begin validation ...
# validation: step 700 | dev_ppl=12.035954475402832
# epoch 3 step 700: save currently the best model to 'model.pt'
# epoch 3 (165/272) | step 710 | avg_nll=18.44 avg_ppl=12.62 speed=2311.31 words/sec time_elapsed=52.21 sec
# epoch 3 (175/272) | step 720 | avg_nll=18.14 avg_ppl=12.21 speed=3540.57 words/sec time_elapsed=52.87 sec
# epoch 3 (185/272) | step 730 | avg_nll=17.57 avg_ppl=11.66 speed=3484.62 words/sec time_elapsed=53.52 sec
# epoch 3 (195/272) | step 740 | avg_nll=18.33 avg_ppl=12.59 speed=3720.57 words/sec time_elapsed=54.15 sec
# epoch 3 (205/272) | step 750 | avg_nll=18.13 avg_ppl=12.19 speed=3537.21 words/sec time_elapsed=54.80 sec
# epoch 3 (215/272) | step 760 | avg_nll=18.17 avg_ppl=12.41 speed=3726.76 words/sec time_elapsed=55.42 sec
# epoch 3 (225/272) | step 770 | avg_nll=18.05 avg_ppl=12.16 speed=3584.68 words/sec time_elapsed=56.07 sec
# epoch 3 (235/272) | step 780 | avg_nll=19.60 avg_ppl=13.68 speed=3852.94 words/sec time_elapsed=56.69 sec
# epoch 3 (245/272) | step 790 | avg_nll=18.35 avg_ppl=12.33 speed=3491.60 words/sec time_elapsed=57.36 sec
# epoch 3 (255/272) | step 800 | avg_nll=17.68 avg_ppl=11.38 speed=3072.85 words/sec time_elapsed=58.12 sec
# Begin validation ...
# validation: step 800 | dev_ppl=11.244246482849121
# epoch 3 step 800: save currently the best model to 'model.pt'
# epoch 3 (265/272) | step 810 | avg_nll=17.53 avg_ppl=11.86 speed=1723.00 words/sec time_elapsed=59.43 sec
# epoch 4 (3/272) | step 820 | avg_nll=17.64 avg_ppl=11.71 speed=2388.64 words/sec time_elapsed=60.39 sec
# epoch 4 (13/272) | step 830 | avg_nll=17.76 avg_ppl=11.17 speed=3433.69 words/sec time_elapsed=61.08 sec
# epoch 4 (23/272) | step 840 | avg_nll=17.32 avg_ppl=11.00 speed=3709.53 words/sec time_elapsed=61.70 sec
# epoch 4 (33/272) | step 850 | avg_nll=16.73 avg_ppl=10.47 speed=3565.79 words/sec time_elapsed=62.34 sec
# epoch 4 (43/272) | step 860 | avg_nll=17.99 avg_ppl=11.71 speed=3897.63 words/sec time_elapsed=62.94 sec
# epoch 4 (53/272) | step 870 | avg_nll=17.58 avg_ppl=11.23 speed=3420.23 words/sec time_elapsed=63.62 sec
# epoch 4 (63/272) | step 880 | avg_nll=17.32 avg_ppl=10.78 speed=3854.97 words/sec time_elapsed=64.23 sec
# epoch 4 (73/272) | step 890 | avg_nll=17.25 avg_ppl=10.77 speed=3715.58 words/sec time_elapsed=64.85 sec
# epoch 4 (83/272) | step 900 | avg_nll=17.82 avg_ppl=11.22 speed=3483.37 words/sec time_elapsed=65.53 sec
# Begin validation ...
# validation: step 900 | dev_ppl=10.445937156677246
# epoch 4 step 900: save currently the best model to 'model.pt'
# epoch 4 (93/272) | step 910 | avg_nll=17.26 avg_ppl=10.75 speed=2368.61 words/sec time_elapsed=66.51 sec
# epoch 4 (103/272) | step 920 | avg_nll=18.25 avg_ppl=11.98 speed=3603.97 words/sec time_elapsed=67.17 sec
# epoch 4 (113/272) | step 930 | avg_nll=17.12 avg_ppl=10.81 speed=3753.61 words/sec time_elapsed=67.78 sec
# epoch 4 (123/272) | step 940 | avg_nll=17.30 avg_ppl=11.09 speed=3399.54 words/sec time_elapsed=68.46 sec
# epoch 4 (133/272) | step 950 | avg_nll=17.83 avg_ppl=11.45 speed=3740.35 words/sec time_elapsed=69.08 sec
# epoch 4 (143/272) | step 960 | avg_nll=16.80 avg_ppl=10.66 speed=3548.29 words/sec time_elapsed=69.72 sec
# epoch 4 (153/272) | step 970 | avg_nll=16.85 avg_ppl=10.45 speed=3558.61 words/sec time_elapsed=70.37 sec
# epoch 4 (163/272) | step 980 | avg_nll=16.58 avg_ppl=9.93 speed=2731.59 words/sec time_elapsed=71.21 sec
# epoch 4 (173/272) | step 990 | avg_nll=17.29 avg_ppl=10.74 speed=2611.39 words/sec time_elapsed=72.11 sec
# epoch 4 (183/272) | step 1000 | avg_nll=16.19 avg_ppl=9.57 speed=2490.76 words/sec time_elapsed=73.03 sec
# Begin validation ...
# validation: step 1000 | dev_ppl=10.20670223236084
# epoch 4 step 1000: save currently the best model to 'model.pt'
# epoch 4 (193/272) | step 1010 | avg_nll=16.95 avg_ppl=10.03 speed=2087.02 words/sec time_elapsed=74.16 sec
# epoch 4 (203/272) | step 1020 | avg_nll=17.24 avg_ppl=10.29 speed=3631.86 words/sec time_elapsed=74.81 sec
# epoch 4 (213/272) | step 1030 | avg_nll=16.99 avg_ppl=10.20 speed=3720.03 words/sec time_elapsed=75.44 sec
# epoch 4 (223/272) | step 1040 | avg_nll=15.90 avg_ppl=9.36 speed=3381.64 words/sec time_elapsed=76.11 sec
# epoch 4 (233/272) | step 1050 | avg_nll=16.18 avg_ppl=9.44 speed=3551.41 words/sec time_elapsed=76.76 sec
# epoch 4 (243/272) | step 1060 | avg_nll=17.39 avg_ppl=10.73 speed=3614.36 words/sec time_elapsed=77.41 sec
# epoch 4 (253/272) | step 1070 | avg_nll=14.98 avg_ppl=8.60 speed=3515.30 words/sec time_elapsed=78.04 sec
# epoch 4 (263/272) | step 1080 | avg_nll=16.91 avg_ppl=10.32 speed=3621.44 words/sec time_elapsed=78.68 sec
# epoch 5 (1/272) | step 1090 | avg_nll=15.70 avg_ppl=9.16 speed=3603.70 words/sec time_elapsed=79.31 sec
# epoch 5 (11/272) | step 1100 | avg_nll=16.10 avg_ppl=9.12 speed=3721.98 words/sec time_elapsed=79.94 sec
# Begin validation ...
# validation: step 1100 | dev_ppl=9.468464851379395
# epoch 5 step 1100: save currently the best model to 'model.pt'
# epoch 5 (21/272) | step 1110 | avg_nll=16.37 avg_ppl=9.50 speed=2415.04 words/sec time_elapsed=80.90 sec
# epoch 5 (31/272) | step 1120 | avg_nll=15.68 avg_ppl=8.78 speed=3740.70 words/sec time_elapsed=81.52 sec
# epoch 5 (41/272) | step 1130 | avg_nll=15.80 avg_ppl=8.82 speed=3480.01 words/sec time_elapsed=82.19 sec
# epoch 5 (51/272) | step 1140 | avg_nll=15.46 avg_ppl=8.79 speed=3715.50 words/sec time_elapsed=82.80 sec
# epoch 5 (61/272) | step 1150 | avg_nll=15.88 avg_ppl=8.99 speed=3697.60 words/sec time_elapsed=83.43 sec
# epoch 5 (71/272) | step 1160 | avg_nll=15.37 avg_ppl=8.59 speed=2618.04 words/sec time_elapsed=84.30 sec
# epoch 5 (81/272) | step 1170 | avg_nll=16.01 avg_ppl=9.33 speed=2515.00 words/sec time_elapsed=85.21 sec
# epoch 5 (91/272) | step 1180 | avg_nll=17.00 avg_ppl=9.61 speed=2466.83 words/sec time_elapsed=86.19 sec
# epoch 5 (101/272) | step 1190 | avg_nll=15.54 avg_ppl=8.80 speed=3339.71 words/sec time_elapsed=86.87 sec
# epoch 5 (111/272) | step 1200 | avg_nll=16.05 avg_ppl=9.17 speed=3386.40 words/sec time_elapsed=87.56 sec
# Begin validation ...
# validation: step 1200 | dev_ppl=9.098849296569824
# epoch 5 step 1200: save currently the best model to 'model.pt'
# epoch 5 (121/272) | step 1210 | avg_nll=16.92 avg_ppl=10.23 speed=2334.50 words/sec time_elapsed=88.55 sec
# epoch 5 (131/272) | step 1220 | avg_nll=15.36 avg_ppl=8.52 speed=3858.85 words/sec time_elapsed=89.15 sec
# epoch 5 (141/272) | step 1230 | avg_nll=16.32 avg_ppl=9.36 speed=3593.22 words/sec time_elapsed=89.80 sec
# epoch 5 (151/272) | step 1240 | avg_nll=15.29 avg_ppl=8.42 speed=3643.27 words/sec time_elapsed=90.43 sec
# epoch 5 (161/272) | step 1250 | avg_nll=16.47 avg_ppl=9.62 speed=3728.12 words/sec time_elapsed=91.05 sec
# epoch 5 (171/272) | step 1260 | avg_nll=15.49 avg_ppl=8.58 speed=3552.55 words/sec time_elapsed=91.70 sec
# epoch 5 (181/272) | step 1270 | avg_nll=14.85 avg_ppl=8.25 speed=3608.38 words/sec time_elapsed=92.33 sec
# epoch 5 (191/272) | step 1280 | avg_nll=15.87 avg_ppl=8.70 speed=3664.28 words/sec time_elapsed=92.97 sec
# epoch 5 (201/272) | step 1290 | avg_nll=15.19 avg_ppl=8.01 speed=3499.04 words/sec time_elapsed=93.63 sec
# epoch 5 (211/272) | step 1300 | avg_nll=15.38 avg_ppl=8.57 speed=3583.48 words/sec time_elapsed=94.27 sec
# Begin validation ...
# validation: step 1300 | dev_ppl=8.517403602600098
# epoch 5 step 1300: save currently the best model to 'model.pt'
# epoch 5 (221/272) | step 1310 | avg_nll=15.90 avg_ppl=8.76 speed=2431.83 words/sec time_elapsed=95.24 sec
# epoch 5 (231/272) | step 1320 | avg_nll=15.82 avg_ppl=8.69 speed=3768.71 words/sec time_elapsed=95.86 sec
# epoch 5 (241/272) | step 1330 | avg_nll=15.15 avg_ppl=8.01 speed=3524.94 words/sec time_elapsed=96.52 sec
# epoch 5 (251/272) | step 1340 | avg_nll=14.81 avg_ppl=8.00 speed=2551.51 words/sec time_elapsed=97.41 sec
# epoch 5 (261/272) | step 1350 | avg_nll=16.40 avg_ppl=9.38 speed=2493.92 words/sec time_elapsed=98.36 sec
# epoch 5 (271/272) | step 1360 | avg_nll=15.72 avg_ppl=8.52 speed=2734.93 words/sec time_elapsed=99.22 sec
# epoch 6 (9/272) | step 1370 | avg_nll=14.63 avg_ppl=7.53 speed=3938.85 words/sec time_elapsed=99.80 sec
# epoch 6 (19/272) | step 1380 | avg_nll=14.21 avg_ppl=7.20 speed=3791.88 words/sec time_elapsed=100.41 sec
# epoch 6 (29/272) | step 1390 | avg_nll=14.73 avg_ppl=7.88 speed=3721.49 words/sec time_elapsed=101.03 sec
# epoch 6 (39/272) | step 1400 | avg_nll=15.24 avg_ppl=8.07 speed=3801.32 words/sec time_elapsed=101.64 sec
# Begin validation ...
# validation: step 1400 | dev_ppl=8.265983581542969
# epoch 6 step 1400: save currently the best model to 'model.pt'
# epoch 6 (49/272) | step 1410 | avg_nll=14.92 avg_ppl=7.92 speed=2349.53 words/sec time_elapsed=102.62 sec
# epoch 6 (59/272) | step 1420 | avg_nll=14.60 avg_ppl=7.36 speed=3750.39 words/sec time_elapsed=103.25 sec
# epoch 6 (69/272) | step 1430 | avg_nll=14.22 avg_ppl=7.15 speed=3907.53 words/sec time_elapsed=103.84 sec
# epoch 6 (79/272) | step 1440 | avg_nll=15.04 avg_ppl=7.96 speed=3906.73 words/sec time_elapsed=104.43 sec
# epoch 6 (89/272) | step 1450 | avg_nll=15.86 avg_ppl=8.55 speed=4016.84 words/sec time_elapsed=105.02 sec
# epoch 6 (99/272) | step 1460 | avg_nll=14.73 avg_ppl=7.75 speed=3841.48 words/sec time_elapsed=105.62 sec
# epoch 6 (109/272) | step 1470 | avg_nll=14.64 avg_ppl=7.59 speed=3960.33 words/sec time_elapsed=106.21 sec
# epoch 6 (119/272) | step 1480 | avg_nll=14.82 avg_ppl=7.69 speed=4047.52 words/sec time_elapsed=106.78 sec
# epoch 6 (129/272) | step 1490 | avg_nll=14.99 avg_ppl=7.89 speed=3982.69 words/sec time_elapsed=107.36 sec
# epoch 6 (139/272) | step 1500 | avg_nll=14.32 avg_ppl=7.23 speed=3961.63 words/sec time_elapsed=107.95 sec
# Begin validation ...
# validation: step 1500 | dev_ppl=7.963902950286865
# epoch 6 step 1500: save currently the best model to 'model.pt'
# epoch 6 (149/272) | step 1510 | avg_nll=15.21 avg_ppl=8.08 speed=2450.82 words/sec time_elapsed=108.90 sec
# epoch 6 (159/272) | step 1520 | avg_nll=14.73 avg_ppl=7.63 speed=3054.07 words/sec time_elapsed=109.66 sec
# epoch 6 (169/272) | step 1530 | avg_nll=13.32 avg_ppl=6.69 speed=2737.65 words/sec time_elapsed=110.48 sec
# epoch 6 (179/272) | step 1540 | avg_nll=14.82 avg_ppl=7.66 speed=2764.90 words/sec time_elapsed=111.32 sec
# epoch 6 (189/272) | step 1550 | avg_nll=14.75 avg_ppl=7.96 speed=2674.24 words/sec time_elapsed=112.17 sec
# epoch 6 (199/272) | step 1560 | avg_nll=14.63 avg_ppl=7.47 speed=3815.24 words/sec time_elapsed=112.78 sec
# epoch 6 (209/272) | step 1570 | avg_nll=13.94 avg_ppl=6.98 speed=3966.33 words/sec time_elapsed=113.36 sec
# epoch 6 (219/272) | step 1580 | avg_nll=15.14 avg_ppl=7.90 speed=3885.42 words/sec time_elapsed=113.97 sec
# epoch 6 (229/272) | step 1590 | avg_nll=15.47 avg_ppl=8.13 speed=3862.82 words/sec time_elapsed=114.58 sec
# epoch 6 (239/272) | step 1600 | avg_nll=14.76 avg_ppl=7.73 speed=3615.61 words/sec time_elapsed=115.22 sec
# Begin validation ...
# validation: step 1600 | dev_ppl=7.549778461456299
# epoch 6 step 1600: save currently the best model to 'model.pt'
# epoch 6 (249/272) | step 1610 | avg_nll=14.97 avg_ppl=7.84 speed=2357.24 words/sec time_elapsed=116.20 sec
# epoch 6 (259/272) | step 1620 | avg_nll=14.11 avg_ppl=6.98 speed=3824.45 words/sec time_elapsed=116.81 sec
# epoch 6 (269/272) | step 1630 | avg_nll=14.35 avg_ppl=7.23 speed=3861.05 words/sec time_elapsed=117.41 sec
# epoch 7 (7/272) | step 1640 | avg_nll=13.55 avg_ppl=6.56 speed=3692.98 words/sec time_elapsed=118.04 sec
# epoch 7 (17/272) | step 1650 | avg_nll=13.61 avg_ppl=6.73 speed=3166.68 words/sec time_elapsed=118.76 sec
# epoch 7 (27/272) | step 1660 | avg_nll=13.05 avg_ppl=6.33 speed=3841.07 words/sec time_elapsed=119.35 sec
# epoch 7 (37/272) | step 1670 | avg_nll=13.67 avg_ppl=6.59 speed=3751.23 words/sec time_elapsed=119.97 sec
# epoch 7 (47/272) | step 1680 | avg_nll=14.54 avg_ppl=7.39 speed=3856.44 words/sec time_elapsed=120.57 sec
# epoch 7 (57/272) | step 1690 | avg_nll=13.32 avg_ppl=6.49 speed=3635.21 words/sec time_elapsed=121.20 sec
# epoch 7 (67/272) | step 1700 | avg_nll=13.63 avg_ppl=6.52 speed=3724.14 words/sec time_elapsed=121.82 sec
# Begin validation ...
# validation: step 1700 | dev_ppl=7.413665294647217
# epoch 7 step 1700: save currently the best model to 'model.pt'
# epoch 7 (77/272) | step 1710 | avg_nll=13.01 avg_ppl=6.13 speed=1793.92 words/sec time_elapsed=123.10 sec
# epoch 7 (87/272) | step 1720 | avg_nll=14.58 avg_ppl=7.19 speed=2816.03 words/sec time_elapsed=123.94 sec
# epoch 7 (97/272) | step 1730 | avg_nll=13.72 avg_ppl=6.76 speed=2509.36 words/sec time_elapsed=124.86 sec
# epoch 7 (107/272) | step 1740 | avg_nll=13.80 avg_ppl=6.54 speed=3794.84 words/sec time_elapsed=125.48 sec
# epoch 7 (117/272) | step 1750 | avg_nll=14.15 avg_ppl=6.95 speed=3851.31 words/sec time_elapsed=126.08 sec
# epoch 7 (127/272) | step 1760 | avg_nll=13.05 avg_ppl=6.16 speed=4024.76 words/sec time_elapsed=126.65 sec
# epoch 7 (137/272) | step 1770 | avg_nll=14.40 avg_ppl=7.10 speed=3697.41 words/sec time_elapsed=127.29 sec
# epoch 7 (147/272) | step 1780 | avg_nll=14.33 avg_ppl=7.16 speed=4010.48 words/sec time_elapsed=127.87 sec
# epoch 7 (157/272) | step 1790 | avg_nll=14.91 avg_ppl=7.52 speed=3837.34 words/sec time_elapsed=128.49 sec
# epoch 7 (167/272) | step 1800 | avg_nll=14.22 avg_ppl=6.96 speed=3915.93 words/sec time_elapsed=129.09 sec
# Begin validation ...
# validation: step 1800 | dev_ppl=7.1761555671691895
# epoch 7 step 1800: save currently the best model to 'model.pt'
# epoch 7 (177/272) | step 1810 | avg_nll=13.92 avg_ppl=6.72 speed=2499.26 words/sec time_elapsed=130.02 sec
# epoch 7 (187/272) | step 1820 | avg_nll=12.85 avg_ppl=6.06 speed=3739.64 words/sec time_elapsed=130.63 sec
# epoch 7 (197/272) | step 1830 | avg_nll=13.73 avg_ppl=6.82 speed=3907.89 words/sec time_elapsed=131.22 sec
# epoch 7 (207/272) | step 1840 | avg_nll=14.25 avg_ppl=7.09 speed=3894.66 words/sec time_elapsed=131.82 sec
# epoch 7 (217/272) | step 1850 | avg_nll=14.37 avg_ppl=7.13 speed=3642.36 words/sec time_elapsed=132.46 sec
# epoch 7 (227/272) | step 1860 | avg_nll=13.77 avg_ppl=6.63 speed=3977.94 words/sec time_elapsed=133.04 sec
# epoch 7 (237/272) | step 1870 | avg_nll=12.88 avg_ppl=5.99 speed=3884.66 words/sec time_elapsed=133.64 sec
# epoch 7 (247/272) | step 1880 | avg_nll=13.24 avg_ppl=6.42 speed=3703.82 words/sec time_elapsed=134.25 sec
# epoch 7 (257/272) | step 1890 | avg_nll=13.62 avg_ppl=6.46 speed=3678.58 words/sec time_elapsed=134.89 sec
# epoch 7 (267/272) | step 1900 | avg_nll=12.74 avg_ppl=5.93 speed=2707.69 words/sec time_elapsed=135.73 sec
# Begin validation ...
# validation: step 1900 | dev_ppl=7.0086894035339355
# epoch 7 step 1900: save currently the best model to 'model.pt'
# epoch 8 (5/272) | step 1910 | avg_nll=12.79 avg_ppl=5.73 speed=1658.98 words/sec time_elapsed=137.15 sec
# epoch 8 (15/272) | step 1920 | avg_nll=12.64 avg_ppl=5.85 speed=2830.78 words/sec time_elapsed=137.96 sec
# epoch 8 (25/272) | step 1930 | avg_nll=13.76 avg_ppl=6.28 speed=3768.70 words/sec time_elapsed=138.59 sec
# epoch 8 (35/272) | step 1940 | avg_nll=12.53 avg_ppl=5.68 speed=3622.63 words/sec time_elapsed=139.23 sec
# epoch 8 (45/272) | step 1950 | avg_nll=12.75 avg_ppl=5.74 speed=3652.35 words/sec time_elapsed=139.87 sec
# epoch 8 (55/272) | step 1960 | avg_nll=12.66 avg_ppl=5.73 speed=3881.54 words/sec time_elapsed=140.47 sec
# epoch 8 (65/272) | step 1970 | avg_nll=13.52 avg_ppl=6.33 speed=3662.43 words/sec time_elapsed=141.11 sec
# epoch 8 (75/272) | step 1980 | avg_nll=12.73 avg_ppl=5.90 speed=3717.23 words/sec time_elapsed=141.73 sec
# epoch 8 (85/272) | step 1990 | avg_nll=12.20 avg_ppl=5.48 speed=3477.28 words/sec time_elapsed=142.39 sec
# epoch 8 (95/272) | step 2000 | avg_nll=13.12 avg_ppl=6.07 speed=3418.55 words/sec time_elapsed=143.07 sec
# Begin validation ...
# validation: step 2000 | dev_ppl=6.723642826080322
# epoch 8 step 2000: save currently the best model to 'model.pt'
# epoch 8 (105/272) | step 2010 | avg_nll=12.50 avg_ppl=5.65 speed=2286.59 words/sec time_elapsed=144.08 sec
# epoch 8 (115/272) | step 2020 | avg_nll=12.42 avg_ppl=5.67 speed=3664.79 words/sec time_elapsed=144.70 sec
# epoch 8 (125/272) | step 2030 | avg_nll=13.42 avg_ppl=6.27 speed=3365.01 words/sec time_elapsed=145.40 sec
# epoch 8 (135/272) | step 2040 | avg_nll=13.22 avg_ppl=6.35 speed=3424.31 words/sec time_elapsed=146.07 sec
# epoch 8 (145/272) | step 2050 | avg_nll=12.28 avg_ppl=5.64 speed=3630.88 words/sec time_elapsed=146.69 sec
# epoch 8 (155/272) | step 2060 | avg_nll=12.81 avg_ppl=5.92 speed=3515.24 words/sec time_elapsed=147.35 sec
# epoch 8 (165/272) | step 2070 | avg_nll=13.03 avg_ppl=6.13 speed=3184.42 words/sec time_elapsed=148.07 sec
# epoch 8 (175/272) | step 2080 | avg_nll=13.08 avg_ppl=6.08 speed=2587.42 words/sec time_elapsed=148.97 sec
# epoch 8 (185/272) | step 2090 | avg_nll=13.16 avg_ppl=6.26 speed=2560.61 words/sec time_elapsed=149.86 sec
# epoch 8 (195/272) | step 2100 | avg_nll=12.18 avg_ppl=5.43 speed=2605.37 words/sec time_elapsed=150.75 sec
# Begin validation ...
# validation: step 2100 | dev_ppl=6.617417335510254
# epoch 8 step 2100: save currently the best model to 'model.pt'
# epoch 8 (205/272) | step 2110 | avg_nll=13.69 avg_ppl=6.35 speed=2466.50 words/sec time_elapsed=151.71 sec
# epoch 8 (215/272) | step 2120 | avg_nll=12.14 avg_ppl=5.50 speed=3570.25 words/sec time_elapsed=152.35 sec
# epoch 8 (225/272) | step 2130 | avg_nll=13.61 avg_ppl=6.62 speed=3715.44 words/sec time_elapsed=152.97 sec
# epoch 8 (235/272) | step 2140 | avg_nll=12.87 avg_ppl=5.88 speed=3624.39 words/sec time_elapsed=153.61 sec
# epoch 8 (245/272) | step 2150 | avg_nll=13.22 avg_ppl=6.09 speed=3872.57 words/sec time_elapsed=154.21 sec
# epoch 8 (255/272) | step 2160 | avg_nll=12.36 avg_ppl=5.61 speed=3196.39 words/sec time_elapsed=154.93 sec
# epoch 8 (265/272) | step 2170 | avg_nll=13.43 avg_ppl=6.15 speed=3811.53 words/sec time_elapsed=155.55 sec
# epoch 9 (3/272) | step 2180 | avg_nll=12.03 avg_ppl=5.47 speed=3709.78 words/sec time_elapsed=156.16 sec
# epoch 9 (13/272) | step 2190 | avg_nll=12.38 avg_ppl=5.46 speed=3665.46 words/sec time_elapsed=156.80 sec
# epoch 9 (23/272) | step 2200 | avg_nll=11.98 avg_ppl=5.29 speed=3737.34 words/sec time_elapsed=157.42 sec
# Begin validation ...
# validation: step 2200 | dev_ppl=6.372946739196777
# epoch 9 step 2200: save currently the best model to 'model.pt'
# epoch 9 (33/272) | step 2210 | avg_nll=11.30 avg_ppl=4.92 speed=2254.63 words/sec time_elapsed=158.42 sec
# epoch 9 (43/272) | step 2220 | avg_nll=12.12 avg_ppl=5.40 speed=3300.33 words/sec time_elapsed=159.12 sec
# epoch 9 (53/272) | step 2230 | avg_nll=12.21 avg_ppl=5.45 speed=3655.70 words/sec time_elapsed=159.75 sec
# epoch 9 (63/272) | step 2240 | avg_nll=12.36 avg_ppl=5.40 speed=3814.65 words/sec time_elapsed=160.37 sec
# epoch 9 (73/272) | step 2250 | avg_nll=11.40 avg_ppl=4.87 speed=2794.25 words/sec time_elapsed=161.19 sec
# epoch 9 (83/272) | step 2260 | avg_nll=12.09 avg_ppl=5.34 speed=2597.83 words/sec time_elapsed=162.08 sec
# epoch 9 (93/272) | step 2270 | avg_nll=11.52 avg_ppl=4.90 speed=2501.62 words/sec time_elapsed=163.01 sec
# epoch 9 (103/272) | step 2280 | avg_nll=12.82 avg_ppl=5.75 speed=2881.04 words/sec time_elapsed=163.82 sec
# epoch 9 (113/272) | step 2290 | avg_nll=12.12 avg_ppl=5.35 speed=3519.31 words/sec time_elapsed=164.48 sec
# epoch 9 (123/272) | step 2300 | avg_nll=11.70 avg_ppl=5.15 speed=3377.53 words/sec time_elapsed=165.16 sec
# Begin validation ...
# validation: step 2300 | dev_ppl=6.404405117034912
# epoch 9 (133/272) | step 2310 | avg_nll=12.05 avg_ppl=5.23 speed=2446.69 words/sec time_elapsed=166.11 sec
# epoch 9 (143/272) | step 2320 | avg_nll=12.29 avg_ppl=5.55 speed=3755.22 words/sec time_elapsed=166.72 sec
# epoch 9 (153/272) | step 2330 | avg_nll=12.20 avg_ppl=5.37 speed=3724.85 words/sec time_elapsed=167.35 sec
# epoch 9 (163/272) | step 2340 | avg_nll=12.16 avg_ppl=5.33 speed=3842.30 words/sec time_elapsed=167.95 sec
# epoch 9 (173/272) | step 2350 | avg_nll=12.21 avg_ppl=5.49 speed=3760.21 words/sec time_elapsed=168.56 sec
# epoch 9 (183/272) | step 2360 | avg_nll=12.15 avg_ppl=5.36 speed=3701.39 words/sec time_elapsed=169.19 sec
# epoch 9 (193/272) | step 2370 | avg_nll=12.72 avg_ppl=5.67 speed=3938.12 words/sec time_elapsed=169.78 sec
# epoch 9 (203/272) | step 2380 | avg_nll=12.44 avg_ppl=5.37 speed=3604.19 words/sec time_elapsed=170.44 sec
# epoch 9 (213/272) | step 2390 | avg_nll=11.94 avg_ppl=5.15 speed=3786.98 words/sec time_elapsed=171.06 sec
# epoch 9 (223/272) | step 2400 | avg_nll=12.97 avg_ppl=5.89 speed=3623.45 words/sec time_elapsed=171.70 sec
# Begin validation ...
# validation: step 2400 | dev_ppl=6.124703407287598
# epoch 9 step 2400: save currently the best model to 'model.pt'
# epoch 9 (233/272) | step 2410 | avg_nll=11.98 avg_ppl=5.22 speed=2322.76 words/sec time_elapsed=172.70 sec
# epoch 9 (243/272) | step 2420 | avg_nll=12.10 avg_ppl=5.41 speed=3606.91 words/sec time_elapsed=173.34 sec
# epoch 9 (253/272) | step 2430 | avg_nll=12.31 avg_ppl=5.47 speed=2608.65 words/sec time_elapsed=174.23 sec
# epoch 9 (263/272) | step 2440 | avg_nll=11.44 avg_ppl=4.86 speed=2672.88 words/sec time_elapsed=175.09 sec
# epoch 10 (1/272) | step 2450 | avg_nll=12.32 avg_ppl=5.43 speed=2488.15 words/sec time_elapsed=176.03 sec
# epoch 10 (11/272) | step 2460 | avg_nll=11.61 avg_ppl=4.99 speed=3167.24 words/sec time_elapsed=176.76 sec
# epoch 10 (21/272) | step 2470 | avg_nll=11.03 avg_ppl=4.50 speed=3665.07 words/sec time_elapsed=177.40 sec
# epoch 10 (31/272) | step 2480 | avg_nll=11.87 avg_ppl=5.05 speed=3696.08 words/sec time_elapsed=178.03 sec
# epoch 10 (41/272) | step 2490 | avg_nll=11.62 avg_ppl=4.86 speed=3731.51 words/sec time_elapsed=178.67 sec
# epoch 10 (51/272) | step 2500 | avg_nll=11.12 avg_ppl=4.67 speed=3644.20 words/sec time_elapsed=179.30 sec
# Begin validation ...
# validation: step 2500 | dev_ppl=5.977702617645264
# epoch 10 step 2500: save currently the best model to 'model.pt'
# epoch 10 (61/272) | step 2510 | avg_nll=11.13 avg_ppl=4.56 speed=2291.76 words/sec time_elapsed=180.32 sec
# epoch 10 (71/272) | step 2520 | avg_nll=11.71 avg_ppl=5.03 speed=3607.52 words/sec time_elapsed=180.97 sec
# epoch 10 (81/272) | step 2530 | avg_nll=11.08 avg_ppl=4.66 speed=3807.93 words/sec time_elapsed=181.57 sec
# epoch 10 (91/272) | step 2540 | avg_nll=11.15 avg_ppl=4.75 speed=3615.85 words/sec time_elapsed=182.21 sec
# epoch 10 (101/272) | step 2550 | avg_nll=11.77 avg_ppl=5.06 speed=3531.51 words/sec time_elapsed=182.86 sec
# epoch 10 (111/272) | step 2560 | avg_nll=10.67 avg_ppl=4.37 speed=3646.01 words/sec time_elapsed=183.50 sec
# epoch 10 (121/272) | step 2570 | avg_nll=11.14 avg_ppl=4.64 speed=3653.21 words/sec time_elapsed=184.13 sec
# epoch 10 (131/272) | step 2580 | avg_nll=11.29 avg_ppl=4.81 speed=3754.99 words/sec time_elapsed=184.75 sec
# epoch 10 (141/272) | step 2590 | avg_nll=11.81 avg_ppl=4.99 speed=3801.33 words/sec time_elapsed=185.37 sec
# epoch 10 (151/272) | step 2600 | avg_nll=11.99 avg_ppl=5.17 speed=3760.16 words/sec time_elapsed=185.99 sec
# Begin validation ...
# validation: step 2600 | dev_ppl=5.900092601776123
# epoch 10 step 2600: save currently the best model to 'model.pt'
# epoch 10 (161/272) | step 2610 | avg_nll=11.44 avg_ppl=4.92 speed=1770.84 words/sec time_elapsed=187.29 sec
# epoch 10 (171/272) | step 2620 | avg_nll=11.49 avg_ppl=4.86 speed=2694.47 words/sec time_elapsed=188.15 sec
# epoch 10 (181/272) | step 2630 | avg_nll=11.82 avg_ppl=5.09 speed=2487.71 words/sec time_elapsed=189.08 sec
# epoch 10 (191/272) | step 2640 | avg_nll=11.41 avg_ppl=4.97 speed=3744.36 words/sec time_elapsed=189.69 sec
# epoch 10 (201/272) | step 2650 | avg_nll=11.45 avg_ppl=5.07 speed=3399.43 words/sec time_elapsed=190.36 sec
# epoch 10 (211/272) | step 2660 | avg_nll=11.38 avg_ppl=4.78 speed=3657.33 words/sec time_elapsed=190.99 sec
# epoch 10 (221/272) | step 2670 | avg_nll=11.48 avg_ppl=4.91 speed=3640.16 words/sec time_elapsed=191.63 sec
# epoch 10 (231/272) | step 2680 | avg_nll=11.06 avg_ppl=4.57 speed=3462.51 words/sec time_elapsed=192.30 sec
# epoch 10 (241/272) | step 2690 | avg_nll=11.21 avg_ppl=4.75 speed=3817.97 words/sec time_elapsed=192.90 sec
# epoch 10 (251/272) | step 2700 | avg_nll=11.65 avg_ppl=4.92 speed=3543.73 words/sec time_elapsed=193.56 sec
# Begin validation ...
# validation: step 2700 | dev_ppl=5.792969226837158
# epoch 10 step 2700: save currently the best model to 'model.pt'
# epoch 10 (261/272) | step 2710 | avg_nll=11.98 avg_ppl=5.25 speed=2383.21 words/sec time_elapsed=194.53 sec
# epoch 10 (271/272) | step 2720 | avg_nll=10.47 avg_ppl=4.38 speed=3535.18 words/sec time_elapsed=195.17 sec
# epoch 11 (9/272) | step 2730 | avg_nll=10.33 avg_ppl=4.22 speed=3553.94 words/sec time_elapsed=195.82 sec
# epoch 11 (19/272) | step 2740 | avg_nll=10.74 avg_ppl=4.44 speed=3568.18 words/sec time_elapsed=196.47 sec
# epoch 11 (29/272) | step 2750 | avg_nll=11.02 avg_ppl=4.61 speed=3394.17 words/sec time_elapsed=197.15 sec
# epoch 11 (39/272) | step 2760 | avg_nll=10.98 avg_ppl=4.49 speed=3695.78 words/sec time_elapsed=197.78 sec
# epoch 11 (49/272) | step 2770 | avg_nll=10.49 avg_ppl=4.30 speed=3798.31 words/sec time_elapsed=198.39 sec
# epoch 11 (59/272) | step 2780 | avg_nll=10.66 avg_ppl=4.26 speed=3653.35 words/sec time_elapsed=199.03 sec
# epoch 11 (69/272) | step 2790 | avg_nll=10.22 avg_ppl=4.17 speed=2487.18 words/sec time_elapsed=199.95 sec
# epoch 11 (79/272) | step 2800 | avg_nll=10.16 avg_ppl=4.18 speed=2476.83 words/sec time_elapsed=200.87 sec
# Begin validation ...
# validation: step 2800 | dev_ppl=5.7863640785217285
# epoch 11 step 2800: save currently the best model to 'model.pt'
# epoch 11 (89/272) | step 2810 | avg_nll=10.17 avg_ppl=4.09 speed=1745.47 words/sec time_elapsed=202.19 sec
# epoch 11 (99/272) | step 2820 | avg_nll=10.19 avg_ppl=4.23 speed=3378.76 words/sec time_elapsed=202.86 sec
# epoch 11 (109/272) | step 2830 | avg_nll=10.98 avg_ppl=4.53 speed=3623.28 words/sec time_elapsed=203.50 sec
# epoch 11 (119/272) | step 2840 | avg_nll=11.34 avg_ppl=4.70 speed=3652.19 words/sec time_elapsed=204.15 sec
# epoch 11 (129/272) | step 2850 | avg_nll=9.76 avg_ppl=3.91 speed=3746.48 words/sec time_elapsed=204.76 sec
# epoch 11 (139/272) | step 2860 | avg_nll=10.78 avg_ppl=4.48 speed=3331.17 words/sec time_elapsed=205.45 sec
# epoch 11 (149/272) | step 2870 | avg_nll=11.14 avg_ppl=4.66 speed=3669.69 words/sec time_elapsed=206.08 sec
# epoch 11 (159/272) | step 2880 | avg_nll=10.92 avg_ppl=4.49 speed=3659.31 words/sec time_elapsed=206.72 sec
# epoch 11 (169/272) | step 2890 | avg_nll=11.08 avg_ppl=4.52 speed=3380.37 words/sec time_elapsed=207.41 sec
# epoch 11 (179/272) | step 2900 | avg_nll=10.34 avg_ppl=4.15 speed=3553.15 words/sec time_elapsed=208.07 sec
# Begin validation ...
# validation: step 2900 | dev_ppl=5.612855911254883
# epoch 11 step 2900: save currently the best model to 'model.pt'
# epoch 11 (189/272) | step 2910 | avg_nll=10.40 avg_ppl=4.26 speed=2402.64 words/sec time_elapsed=209.02 sec
# epoch 11 (199/272) | step 2920 | avg_nll=12.15 avg_ppl=5.09 speed=3814.53 words/sec time_elapsed=209.65 sec
# epoch 11 (209/272) | step 2930 | avg_nll=10.42 avg_ppl=4.21 speed=3619.28 words/sec time_elapsed=210.29 sec
# epoch 11 (219/272) | step 2940 | avg_nll=11.14 avg_ppl=4.60 speed=3720.24 words/sec time_elapsed=210.92 sec
# epoch 11 (229/272) | step 2950 | avg_nll=10.96 avg_ppl=4.60 speed=3680.94 words/sec time_elapsed=211.54 sec
# epoch 11 (239/272) | step 2960 | avg_nll=10.56 avg_ppl=4.42 speed=3022.56 words/sec time_elapsed=212.29 sec
# epoch 11 (249/272) | step 2970 | avg_nll=10.77 avg_ppl=4.40 speed=2620.95 words/sec time_elapsed=213.18 sec
# epoch 11 (259/272) | step 2980 | avg_nll=11.49 avg_ppl=4.75 speed=2587.93 words/sec time_elapsed=214.09 sec
# epoch 11 (269/272) | step 2990 | avg_nll=11.11 avg_ppl=4.51 speed=2847.08 words/sec time_elapsed=214.92 sec
# epoch 12 (7/272) | step 3000 | avg_nll=10.35 avg_ppl=4.25 speed=3771.64 words/sec time_elapsed=215.53 sec
# Begin validation ...
# validation: step 3000 | dev_ppl=5.5615081787109375
# epoch 12 step 3000: save currently the best model to 'model.pt'
# epoch 12 (17/272) | step 3010 | avg_nll=10.72 avg_ppl=4.23 speed=2350.97 words/sec time_elapsed=216.54 sec
# epoch 12 (27/272) | step 3020 | avg_nll=9.19 avg_ppl=3.67 speed=3774.19 words/sec time_elapsed=217.14 sec
# epoch 12 (37/272) | step 3030 | avg_nll=9.90 avg_ppl=3.89 speed=3729.46 words/sec time_elapsed=217.77 sec
# epoch 12 (47/272) | step 3040 | avg_nll=10.58 avg_ppl=4.22 speed=3785.16 words/sec time_elapsed=218.39 sec
# epoch 12 (57/272) | step 3050 | avg_nll=9.98 avg_ppl=3.90 speed=3439.20 words/sec time_elapsed=219.07 sec
# epoch 12 (67/272) | step 3060 | avg_nll=10.78 avg_ppl=4.41 speed=3626.35 words/sec time_elapsed=219.71 sec
# epoch 12 (77/272) | step 3070 | avg_nll=9.70 avg_ppl=3.87 speed=3589.47 words/sec time_elapsed=220.35 sec
# epoch 12 (87/272) | step 3080 | avg_nll=10.32 avg_ppl=4.21 speed=3887.02 words/sec time_elapsed=220.94 sec
# epoch 12 (97/272) | step 3090 | avg_nll=9.90 avg_ppl=4.07 speed=3492.76 words/sec time_elapsed=221.59 sec
# epoch 12 (107/272) | step 3100 | avg_nll=10.34 avg_ppl=4.13 speed=3613.61 words/sec time_elapsed=222.23 sec
# Begin validation ...
# validation: step 3100 | dev_ppl=5.487604141235352
# epoch 12 step 3100: save currently the best model to 'model.pt'
# epoch 12 (117/272) | step 3110 | avg_nll=10.40 avg_ppl=4.13 speed=2433.51 words/sec time_elapsed=223.20 sec
# epoch 12 (127/272) | step 3120 | avg_nll=10.95 avg_ppl=4.44 speed=3464.57 words/sec time_elapsed=223.88 sec
# epoch 12 (137/272) | step 3130 | avg_nll=9.89 avg_ppl=3.96 speed=3794.30 words/sec time_elapsed=224.48 sec
# epoch 12 (147/272) | step 3140 | avg_nll=9.81 avg_ppl=3.92 speed=2711.59 words/sec time_elapsed=225.33 sec
# epoch 12 (157/272) | step 3150 | avg_nll=8.82 avg_ppl=3.50 speed=2539.52 words/sec time_elapsed=226.22 sec
# epoch 12 (167/272) | step 3160 | avg_nll=10.05 avg_ppl=3.97 speed=2533.16 words/sec time_elapsed=227.14 sec
# epoch 12 (177/272) | step 3170 | avg_nll=10.20 avg_ppl=4.12 speed=3040.86 words/sec time_elapsed=227.90 sec
# epoch 12 (187/272) | step 3180 | avg_nll=9.96 avg_ppl=3.97 speed=3562.32 words/sec time_elapsed=228.55 sec
# epoch 12 (197/272) | step 3190 | avg_nll=9.92 avg_ppl=3.94 speed=3784.03 words/sec time_elapsed=229.16 sec
# epoch 12 (207/272) | step 3200 | avg_nll=10.21 avg_ppl=4.07 speed=3749.71 words/sec time_elapsed=229.78 sec
# Begin validation ...
# validation: step 3200 | dev_ppl=5.4110236167907715
# epoch 12 step 3200: save currently the best model to 'model.pt'
# epoch 12 (217/272) | step 3210 | avg_nll=10.50 avg_ppl=4.18 speed=2438.07 words/sec time_elapsed=230.74 sec
# epoch 12 (227/272) | step 3220 | avg_nll=9.68 avg_ppl=3.84 speed=3764.21 words/sec time_elapsed=231.36 sec
# epoch 12 (237/272) | step 3230 | avg_nll=9.82 avg_ppl=3.91 speed=3657.46 words/sec time_elapsed=231.99 sec
# epoch 12 (247/272) | step 3240 | avg_nll=10.65 avg_ppl=4.24 speed=3452.97 words/sec time_elapsed=232.67 sec
# epoch 12 (257/272) | step 3250 | avg_nll=10.81 avg_ppl=4.51 speed=3282.81 words/sec time_elapsed=233.37 sec
# epoch 12 (267/272) | step 3260 | avg_nll=10.32 avg_ppl=4.13 speed=3631.45 words/sec time_elapsed=234.01 sec
# epoch 13 (5/272) | step 3270 | avg_nll=9.73 avg_ppl=3.81 speed=3650.08 words/sec time_elapsed=234.65 sec
# epoch 13 (15/272) | step 3280 | avg_nll=9.49 avg_ppl=3.63 speed=3630.85 words/sec time_elapsed=235.30 sec
# epoch 13 (25/272) | step 3290 | avg_nll=9.35 avg_ppl=3.63 speed=3847.15 words/sec time_elapsed=235.90 sec
# epoch 13 (35/272) | step 3300 | avg_nll=8.82 avg_ppl=3.45 speed=3529.12 words/sec time_elapsed=236.55 sec
# Begin validation ...
# validation: step 3300 | dev_ppl=5.384568691253662
# epoch 13 step 3300: save currently the best model to 'model.pt'
# epoch 13 (45/272) | step 3310 | avg_nll=9.16 avg_ppl=3.63 speed=2384.75 words/sec time_elapsed=237.50 sec
# epoch 13 (55/272) | step 3320 | avg_nll=9.70 avg_ppl=3.79 speed=2821.79 words/sec time_elapsed=238.33 sec
# epoch 13 (65/272) | step 3330 | avg_nll=10.03 avg_ppl=3.94 speed=2625.55 words/sec time_elapsed=239.22 sec
# epoch 13 (75/272) | step 3340 | avg_nll=10.43 avg_ppl=4.11 speed=2556.83 words/sec time_elapsed=240.14 sec
# epoch 13 (85/272) | step 3350 | avg_nll=9.39 avg_ppl=3.64 speed=3250.36 words/sec time_elapsed=240.86 sec
# epoch 13 (95/272) | step 3360 | avg_nll=9.95 avg_ppl=3.90 speed=3794.91 words/sec time_elapsed=241.47 sec
# epoch 13 (105/272) | step 3370 | avg_nll=10.19 avg_ppl=4.06 speed=3466.33 words/sec time_elapsed=242.14 sec
# epoch 13 (115/272) | step 3380 | avg_nll=9.10 avg_ppl=3.52 speed=3443.68 words/sec time_elapsed=242.82 sec
# epoch 13 (125/272) | step 3390 | avg_nll=9.83 avg_ppl=3.92 speed=3604.20 words/sec time_elapsed=243.45 sec
# epoch 13 (135/272) | step 3400 | avg_nll=9.48 avg_ppl=3.69 speed=3660.70 words/sec time_elapsed=244.09 sec
# Begin validation ...
# validation: step 3400 | dev_ppl=5.334094524383545
# epoch 13 step 3400: save currently the best model to 'model.pt'
# epoch 13 (145/272) | step 3410 | avg_nll=9.77 avg_ppl=3.93 speed=2460.04 words/sec time_elapsed=245.02 sec
# epoch 13 (155/272) | step 3420 | avg_nll=9.80 avg_ppl=3.85 speed=3747.30 words/sec time_elapsed=245.64 sec
# epoch 13 (165/272) | step 3430 | avg_nll=9.72 avg_ppl=3.91 speed=3658.05 words/sec time_elapsed=246.26 sec
# epoch 13 (175/272) | step 3440 | avg_nll=9.19 avg_ppl=3.56 speed=3765.84 words/sec time_elapsed=246.88 sec
# epoch 13 (185/272) | step 3450 | avg_nll=9.78 avg_ppl=3.81 speed=3892.14 words/sec time_elapsed=247.48 sec
# epoch 13 (195/272) | step 3460 | avg_nll=9.56 avg_ppl=3.72 speed=3779.30 words/sec time_elapsed=248.09 sec
# epoch 13 (205/272) | step 3470 | avg_nll=9.73 avg_ppl=3.88 speed=3747.21 words/sec time_elapsed=248.71 sec
# epoch 13 (215/272) | step 3480 | avg_nll=8.80 avg_ppl=3.43 speed=3633.53 words/sec time_elapsed=249.34 sec
# epoch 13 (225/272) | step 3490 | avg_nll=10.03 avg_ppl=4.00 speed=3777.59 words/sec time_elapsed=249.95 sec
# epoch 13 (235/272) | step 3500 | avg_nll=9.66 avg_ppl=3.77 speed=3159.07 words/sec time_elapsed=250.69 sec
# Begin validation ...
# validation: step 3500 | dev_ppl=5.197301864624023
# epoch 13 step 3500: save currently the best model to 'model.pt'
# epoch 13 (245/272) | step 3510 | avg_nll=8.77 avg_ppl=3.39 speed=1696.73 words/sec time_elapsed=252.04 sec
# epoch 13 (255/272) | step 3520 | avg_nll=9.86 avg_ppl=3.87 speed=2336.23 words/sec time_elapsed=253.04 sec
# epoch 13 (265/272) | step 3530 | avg_nll=9.65 avg_ppl=3.78 speed=3282.32 words/sec time_elapsed=253.75 sec
# epoch 14 (3/272) | step 3540 | avg_nll=8.95 avg_ppl=3.55 speed=3525.81 words/sec time_elapsed=254.39 sec
# epoch 14 (13/272) | step 3550 | avg_nll=9.61 avg_ppl=3.71 speed=3522.66 words/sec time_elapsed=255.06 sec
# epoch 14 (23/272) | step 3560 | avg_nll=8.73 avg_ppl=3.34 speed=3519.02 words/sec time_elapsed=255.71 sec
# epoch 14 (33/272) | step 3570 | avg_nll=9.23 avg_ppl=3.45 speed=3561.84 words/sec time_elapsed=256.38 sec
# epoch 14 (43/272) | step 3580 | avg_nll=9.16 avg_ppl=3.51 speed=3604.67 words/sec time_elapsed=257.03 sec
# epoch 14 (53/272) | step 3590 | avg_nll=8.70 avg_ppl=3.33 speed=3708.53 words/sec time_elapsed=257.66 sec
# epoch 14 (63/272) | step 3600 | avg_nll=9.31 avg_ppl=3.63 speed=3460.48 words/sec time_elapsed=258.32 sec
# Begin validation ...
# validation: step 3600 | dev_ppl=5.144155025482178
# epoch 14 step 3600: save currently the best model to 'model.pt'
# epoch 14 (73/272) | step 3610 | avg_nll=8.64 avg_ppl=3.38 speed=2273.77 words/sec time_elapsed=259.32 sec
# epoch 14 (83/272) | step 3620 | avg_nll=8.99 avg_ppl=3.47 speed=3496.87 words/sec time_elapsed=259.98 sec
# epoch 14 (93/272) | step 3630 | avg_nll=9.41 avg_ppl=3.60 speed=3581.25 words/sec time_elapsed=260.64 sec
# epoch 14 (103/272) | step 3640 | avg_nll=9.13 avg_ppl=3.54 speed=3689.98 words/sec time_elapsed=261.27 sec
# epoch 14 (113/272) | step 3650 | avg_nll=8.34 avg_ppl=3.20 speed=3486.08 words/sec time_elapsed=261.92 sec
# epoch 14 (123/272) | step 3660 | avg_nll=9.04 avg_ppl=3.53 speed=3450.30 words/sec time_elapsed=262.59 sec
# epoch 14 (133/272) | step 3670 | avg_nll=8.39 avg_ppl=3.25 speed=3511.17 words/sec time_elapsed=263.24 sec
# epoch 14 (143/272) | step 3680 | avg_nll=8.96 avg_ppl=3.44 speed=2521.05 words/sec time_elapsed=264.16 sec
# epoch 14 (153/272) | step 3690 | avg_nll=8.83 avg_ppl=3.43 speed=2520.08 words/sec time_elapsed=265.07 sec
# epoch 14 (163/272) | step 3700 | avg_nll=9.63 avg_ppl=3.68 speed=2391.25 words/sec time_elapsed=266.06 sec
# Begin validation ...
# validation: step 3700 | dev_ppl=5.108913898468018
# epoch 14 step 3700: save currently the best model to 'model.pt'
# epoch 14 (173/272) | step 3710 | avg_nll=9.48 avg_ppl=3.65 speed=2316.70 words/sec time_elapsed=267.07 sec
# epoch 14 (183/272) | step 3720 | avg_nll=9.39 avg_ppl=3.67 speed=3656.89 words/sec time_elapsed=267.70 sec
# epoch 14 (193/272) | step 3730 | avg_nll=9.48 avg_ppl=3.68 speed=3637.06 words/sec time_elapsed=268.34 sec
# epoch 14 (203/272) | step 3740 | avg_nll=8.72 avg_ppl=3.36 speed=3496.65 words/sec time_elapsed=269.00 sec
# epoch 14 (213/272) | step 3750 | avg_nll=9.27 avg_ppl=3.57 speed=3643.64 words/sec time_elapsed=269.64 sec
# epoch 14 (223/272) | step 3760 | avg_nll=9.28 avg_ppl=3.61 speed=3188.01 words/sec time_elapsed=270.37 sec
# epoch 14 (233/272) | step 3770 | avg_nll=8.85 avg_ppl=3.39 speed=3511.88 words/sec time_elapsed=271.03 sec
# epoch 14 (243/272) | step 3780 | avg_nll=9.54 avg_ppl=3.76 speed=3593.58 words/sec time_elapsed=271.67 sec
# epoch 14 (253/272) | step 3790 | avg_nll=8.51 avg_ppl=3.31 speed=3464.24 words/sec time_elapsed=272.33 sec
# epoch 14 (263/272) | step 3800 | avg_nll=9.21 avg_ppl=3.53 speed=3922.62 words/sec time_elapsed=272.92 sec
# Begin validation ...
# validation: step 3800 | dev_ppl=5.034417152404785
# epoch 14 step 3800: save currently the best model to 'model.pt'
# epoch 15 (1/272) | step 3810 | avg_nll=9.07 avg_ppl=3.51 speed=2406.08 words/sec time_elapsed=273.88 sec
# epoch 15 (11/272) | step 3820 | avg_nll=8.78 avg_ppl=3.33 speed=3558.42 words/sec time_elapsed=274.54 sec
# epoch 15 (21/272) | step 3830 | avg_nll=8.86 avg_ppl=3.33 speed=3544.66 words/sec time_elapsed=275.20 sec
# epoch 15 (31/272) | step 3840 | avg_nll=8.26 avg_ppl=3.19 speed=3614.69 words/sec time_elapsed=275.83 sec
# epoch 15 (41/272) | step 3850 | avg_nll=8.31 avg_ppl=3.16 speed=2938.08 words/sec time_elapsed=276.62 sec
# epoch 15 (51/272) | step 3860 | avg_nll=8.16 avg_ppl=3.08 speed=2586.85 words/sec time_elapsed=277.52 sec
# epoch 15 (61/272) | step 3870 | avg_nll=8.86 avg_ppl=3.32 speed=2551.68 words/sec time_elapsed=278.44 sec
# epoch 15 (71/272) | step 3880 | avg_nll=8.54 avg_ppl=3.22 speed=2905.86 words/sec time_elapsed=279.25 sec
# epoch 15 (81/272) | step 3890 | avg_nll=8.17 avg_ppl=3.11 speed=3629.41 words/sec time_elapsed=279.88 sec
# epoch 15 (91/272) | step 3900 | avg_nll=8.59 avg_ppl=3.29 speed=3622.92 words/sec time_elapsed=280.52 sec
# Begin validation ...
# validation: step 3900 | dev_ppl=4.999959468841553
# epoch 15 step 3900: save currently the best model to 'model.pt'
# epoch 15 (101/272) | step 3910 | avg_nll=7.70 avg_ppl=2.88 speed=2427.23 words/sec time_elapsed=281.48 sec
# epoch 15 (111/272) | step 3920 | avg_nll=8.42 avg_ppl=3.21 speed=3528.76 words/sec time_elapsed=282.13 sec
# epoch 15 (121/272) | step 3930 | avg_nll=7.65 avg_ppl=2.93 speed=3470.23 words/sec time_elapsed=282.79 sec
# epoch 15 (131/272) | step 3940 | avg_nll=8.59 avg_ppl=3.25 speed=3759.09 words/sec time_elapsed=283.41 sec
# epoch 15 (141/272) | step 3950 | avg_nll=8.88 avg_ppl=3.32 speed=3635.97 words/sec time_elapsed=284.06 sec
# epoch 15 (151/272) | step 3960 | avg_nll=8.92 avg_ppl=3.39 speed=3529.39 words/sec time_elapsed=284.73 sec
# epoch 15 (161/272) | step 3970 | avg_nll=8.87 avg_ppl=3.41 speed=3565.19 words/sec time_elapsed=285.38 sec
# epoch 15 (171/272) | step 3980 | avg_nll=8.77 avg_ppl=3.33 speed=3543.27 words/sec time_elapsed=286.03 sec
# epoch 15 (181/272) | step 3990 | avg_nll=8.66 avg_ppl=3.37 speed=3618.70 words/sec time_elapsed=286.66 sec
# epoch 15 (191/272) | step 4000 | avg_nll=7.98 avg_ppl=3.04 speed=3473.77 words/sec time_elapsed=287.33 sec
# Begin validation ...
# validation: step 4000 | dev_ppl=4.998923301696777
# epoch 15 step 4000: save currently the best model to 'model.pt'
# epoch 15 (201/272) | step 4010 | avg_nll=9.04 avg_ppl=3.49 speed=2264.71 words/sec time_elapsed=288.35 sec
# epoch 15 (211/272) | step 4020 | avg_nll=8.36 avg_ppl=3.16 speed=3743.35 words/sec time_elapsed=288.97 sec
# epoch 15 (221/272) | step 4030 | avg_nll=9.18 avg_ppl=3.60 speed=2558.27 words/sec time_elapsed=289.87 sec
# epoch 15 (231/272) | step 4040 | avg_nll=8.82 avg_ppl=3.36 speed=2617.17 words/sec time_elapsed=290.76 sec
# epoch 15 (241/272) | step 4050 | avg_nll=8.44 avg_ppl=3.23 speed=2350.60 words/sec time_elapsed=291.74 sec
# epoch 15 (251/272) | step 4060 | avg_nll=9.36 avg_ppl=3.63 speed=3362.13 words/sec time_elapsed=292.43 sec
# epoch 15 (261/272) | step 4070 | avg_nll=8.73 avg_ppl=3.39 speed=3403.78 words/sec time_elapsed=293.10 sec
# epoch 15 (271/272) | step 4080 | avg_nll=9.21 avg_ppl=3.63 speed=3803.25 words/sec time_elapsed=293.70 sec
# Reached maximum number of epochs

# %% [markdown]
# ## Evaluate the model
#
# We have trained a seq2seq model for the NMT task. Now let's evaluate the model on the test set by generating translations with beam search and comparing them to the gold translations using the BLEU score.

# %%
from tqdm import tqdm
from nltk.translate.bleu_score import corpus_bleu

def beam_search(model: EncoderDecoderModel,
                encoder_input_ids: torch.LongTensor,
                beam_width: int = 5,
                max_len: int = 32) -> Tuple[torch.LongTensor, float]:
    """Run beam search on the encoder-decoder model for a single source sequence.

    Args:
        model: The encoder-decoder model.
        encoder_input_ids: The input sequence. Tensor of shape [encoder_sequence_length].
        beam_width: Number of generations to expand at each time step.
        max_len: Stop generation when reaching this length for the generated sequence.

    Returns:
        A tuple (generation, score) where generation is the generated target sequence and
            a tensor of shape [target_sequence_length] and score is the corresponding
            log-probability of this generation.
    """
    model.eval()

    encoder_input_ids = encoder_input_ids.unsqueeze(0) # Add the batch dimension
    encoder_padding_mask = torch.zeros_like(encoder_input_ids, dtype=torch.bool) # No padding
    encoder_outputs = model.forward_encoder(encoder_input_ids, encoder_padding_mask)

    generations = [torch.tensor([target_tokenizer.bos_token_id], device=encoder_input_ids.device)]
    scores = [0.0]

    best_generation = None
    best_score = float('-inf')

    for _ in range(max_len):
        new_generations = []
        new_scores = []
        for score, generation in zip(scores, generations):
            generation = generation.unsqueeze(0) # Add the batch dimension
            padding_mask = torch.zeros_like(generation, dtype=torch.bool) # No padding
            decoder_output = model.forward_decoder(generation, padding_mask, encoder_outputs, encoder_padding_mask)
            last_log_probs = decoder_output[0, -1, :].log_softmax(dim=-1)
            top_log_probs, top_indices = last_log_probs.topk(beam_width, dim=-1)

            new_generations.append(torch.cat([generation.expand(beam_width, -1), top_indices[:,None]], dim=1))
            new_scores.append(score + top_log_probs)

        new_generations = torch.cat(new_generations, dim=0)
        new_scores = torch.cat(new_scores, dim=0)

        ends_with_eos = target_tokenizer.eos_token_id == new_generations[:,-1]

        if ends_with_eos.any():
            new_completed_generations = new_generations[ends_with_eos]
            new_completed_scores = new_scores[ends_with_eos]

            if new_completed_scores.max() > best_score:
                best_score = new_completed_scores.max()
                best_generation = new_completed_generations[new_completed_scores.argmax()]

        if best_score >= new_scores.max():
            break

        scores, indices = torch.topk(new_scores, beam_width, dim=-1)
        generations = new_generations[indices]

    if best_generation is None:
        best_generation = generations[0]
        best_score = scores[0]

    return best_generation, best_score.cpu().item()


def run_generation(model, test_dataset, beam_size=5, max_decoding_time_step=32):
    """Run beam search decoding on the test set, compute BLEU and return reference and candidate target sentences.
    """

    device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
    print('Use device: %s' % device)

    input_sentences = []
    reference_sentences = []
    candidate_sentences = []

    with torch.no_grad():
        for example in tqdm(test_dataset):
            encoder_input_ids = torch.tensor(example["encoder_input_ids"], device=device)

            generation, _ = beam_search(model, encoder_input_ids, beam_size, max_decoding_time_step)

            # Decode given source sequence and generated target sequence and avoid special tokens

            input_text = "".join(source_tokenizer.decode(token).replace("▁", " ") for token in example["encoder_input_ids"][1:-1])
            reference_text = "".join(target_tokenizer.decode(token).replace("▁", " ") for token in example["decoder_input_ids"][1:-1])
            candidate_text = "".join(target_tokenizer.decode(token).replace("▁", " ") for token in generation[1:-1].cpu())

            reference_sentences.append(reference_text)
            candidate_sentences.append(candidate_text)
            input_sentences.append(input_text)


    bleu_score = corpus_bleu([[ref] for ref in reference_sentences],
                             [candidate for candidate in candidate_sentences])

    return bleu_score, input_sentences, reference_sentences, candidate_sentences

# %%
# Restore the best validation checkpoint
model.load_state_dict(torch.load("model.pt"))

bleu_score, inputs, references, candidates = run_generation(model, tokenized_datasets["test"])
print('\n\nCorpus BLEU: {}'.format(bleu_score * 100))
# Out:
# Use device: cpu
# 100%|██████████| 486/486 [00:44<00:00, 11.03it/s]
# Corpus BLEU: 54.7786368550147

# %% [markdown]
# Let's look at some examples. What do you think of the quality of the translations?

# %%
# Feel free to change the range to look at more samples!
for k in range(10, 20):
  print(f"===== Sample {k} =====")
  print(f"Input: {inputs[k]}")
  print(f"Gold: {references[k]}")
  print(f"Pred: {candidates[k]}")
# Out:
# ===== Sample 10 =====
# Input:  vous me mettez mal a l aise .
# Gold:  you re embarrassing me .
# Pred:  you re winning .
# ===== Sample 11 =====
# Input:  c est toi le professeur .
# Gold:  you re the teacher .
# Pred:  you re the teacher .
# ===== Sample 12 =====
# Input:  elle sourit avec bonheur .
# Gold:  she smiled happily .
# Pred:  she s getting good him .
# ===== Sample 13 =====
# Input:  je ne suis pas devin .
# Gold:  i m not a psychic .
# Pred:  i m not married .
# ===== Sample 14 =====
# Input:  vous allez perdre .
# Gold:  you re going to lose .
# Pred:  you re going to go .
# ===== Sample 15 =====
# Input:  vous me touchez .
# Gold:  you re touching me .
# Pred:  you re embarrassing me .
# ===== Sample 16 =====
# Input:  je pars aujourd hui .
# Gold:  i m leaving today .
# Pred:  i m leaving today .
# ===== Sample 17 =====
# Input:  je ne suis pas une sainte .
# Gold:  i m no saint .
# Pred:  i m no saint .
# ===== Sample 18 =====
# Input:  je suis puissant .
# Gold:  i m powerful .
# Pred:  i m stubborn .
# ===== Sample 19 =====
# Input:  vous n etes qu un lache .
# Gold:  you re nothing but a coward .
# Pred:  you re just a man .

# %%
def analyze_batch_statistics(dataset, batch_size=32, num_batches=100):
    train_loader = torch.utils.data.DataLoader(
        dataset, batch_size=batch_size, shuffle=True, collate_fn=collate_fn
    )

    total_encoder_tokens = 0
    total_encoder_pads = 0
    total_decoder_tokens = 0
    total_decoder_pads = 0

    for i, batch in enumerate(train_loader):
        if i >= num_batches:
            break

        encoder_pads = batch["encoder_padding_mask"].sum().item()
        decoder_pads = batch["decoder_padding_mask"].sum().item()

        total_encoder_tokens += batch["encoder_input_ids"].numel()
        total_encoder_pads += encoder_pads
        total_decoder_tokens += batch["decoder_input_ids"].numel()
        total_decoder_pads += decoder_pads

    avg_encoder_tokens = total_encoder_tokens / (num_batches * batch_size)
    avg_decoder_tokens = total_decoder_tokens / (num_batches * batch_size)
    encoder_pad_ratio = total_encoder_pads / total_encoder_tokens
    decoder_pad_ratio = total_decoder_pads / total_decoder_tokens

    return {
        "avg_encoder_tokens": avg_encoder_tokens,
        "avg_decoder_tokens": avg_decoder_tokens,
        "encoder_pad_ratio": encoder_pad_ratio,
        "decoder_pad_ratio": decoder_pad_ratio
    }

stats = analyze_batch_statistics(tokenized_datasets["train"])

# %%
print(f"Average source tokens per sequence: {stats['avg_encoder_tokens']:.1f}")
print(f"Average target tokens per sequence: {stats['avg_decoder_tokens']:.1f}")
print(f"Proportion of padding in source: {stats['encoder_pad_ratio']*100:.1f}%")
print(f"Proportion of padding in target: {stats['decoder_pad_ratio']*100:.1f}%")
# Out:
# Average source tokens per sequence: 13.4
# Average target tokens per sequence: 11.7
# Proportion of padding in source: 32.9%
# Proportion of padding in target: 29.2%

# %% [markdown]
# # Questions
#
# Please answer written questions from the assignment in this section. You can alter the provided code to obtain the answers, but be careful not to break anything!
#
# **(b) (4 points)**
#
# - (i)
#     What vocabulary size are we using for the source and target language?
#
# - (ii)
#     Approximately how many source and target tokens are on average contained in a training batch? What proportion of these tokens are `<pad>` tokens on average?
#
# - (iii)
# What is the specific purpose of saving the model parameters in a file `model.pt` throughout training in the code we provide?
#
# **(c) (2 points)**
# Manually look at some results and compare them with the gold answers. What do you think of the quality of the translations? Are these grammatical English sentences? Can you identify any common mistakes?
#
# **(d) (4 points)**
# Consider the provided beam search method. This implementation is not efficient and performs a lot of repeated computation. Identify the issue and propose how you can fix it.
# In particular, describe how would you have to change the arguments and return values of your EncoderDecoderModel and its sub-modules?

# %% [markdown]
# *   (b)(i) vocab_size = 3200
# *   (ii) French Sequence (source) contains on avg 13.4 tokens while English tokens avg are 11.7, approximately 32.9% of tokens in French is padding tokens and 29.25% in English
# *   (iii) we save the model parameters to help us recover if training is interrupted and to make sure training is flexible and robust. Also it might help in deployment.
# * (c) there are right transtations (11, 16,17) and translations where most of the sentence is correctly translated (10,13,14,15,18) and some that are completely incorrect (12,19)
# Most of the translated sentences are grammaticaly correct but in sentence 12, the sentence was definitely not correctly translated nor gramatically correct.
# The words after common words (she,you,are,am,not) are the words that are mostly wrong translated.
# * (d) To improve the efficiency of beam search decoding, it is essential to ensure that the encoder processes the input sequence only once. Since the input remains constant across all beam candidates, repeatedly computing the encoder's output for each beam is redundant and inefficient. Instead, the encoder should be designed to run a single time and return all necessary intermediate outputs—such as hidden states or contextual representations—which the decoder can then reuse throughout the decoding process. This avoids recomputation and significantly speeds up inference. On the other hand, the decoder must be structured to accept these precomputed encoder outputs as input, along with the decoder's current inputs, such as the partial target sequences generated so far. At each decoding step, the decoder combines the fixed encoder representations with the evolving decoder state to predict the next token. This separation of roles ensures that the encoder contributes once, and the decoder dynamically generates output based on that fixed context, thereby optimizing both computational efficiency and performance during beam search
